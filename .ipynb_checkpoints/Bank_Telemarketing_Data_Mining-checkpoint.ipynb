# %% [markdown]
# # <center> Predicting whether Marketing Campaigns will Success

# %% [markdown]
# # Table of Contents
#
# 1. **[Step 1 - Environment Preparation](#step1)**
# 2. **[Step 2 - Exploratory Data Analysis](#step2)**
# 3. **[Step 3 - Data Wrangling](#step3)**
# 4. **[Step 4 - Data Modeling with Machine Learning](#step4)**
# 5. **[Step 5 - Conclusion](#step5)**

# %% [markdown]
# <a id="step1"><a/>
# # 1. Step 1 - Environment Preparation
# Environment Preparation refers to loading essential packages, loading and skimming the dataset.

# %% [markdown]
# ## 1.1 Import Necessary Packages

# %%
# Load Essential Libraries
import sys
print("Python version: {}". format(sys.version))

import pandas as pd #collection of functions for data processing and analysis modeled after R dataframes with SQL like features
print("Pandas version: {}". format(pd.__version__))

import matplotlib #collection of functions for scientific and publication-ready visualization
print("Matplotlib version: {}". format(matplotlib.__version__))

import numpy as np #foundational package for scientific computing
print("NumPy version: {}". format(np.__version__))

import scipy as sp #collection of functions for scientific computing and advance mathematics
print("SciPy version: {}". format(sp.__version__)) 

import sklearn #collection of machine learning algorithms
print("Scikit-learn version: {}". format(sklearn.__version__))

import IPython
from IPython import display #pretty printing of dataframes in Jupyter notebook
print("IPython version: {}". format(IPython.__version__)) 

#misc libraries
import random
import time

#ignore warnings
import warnings
warnings.filterwarnings('ignore')
print('-'*25)

# Input data files are available in the "./Bank_Data_20C/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in Bank_Data_20C directory

# from subprocess import check_output
# print(check_output(["ls", "./Bank_Data_20C"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

#Common Model Algorithms
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

#Common Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MinMaxScaler, StandardScaler, RobustScaler
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold, KFold, GridSearchCV
from sklearn.metrics import f1_score, roc_auc_score,accuracy_score,confusion_matrix, precision_recall_curve, auc, roc_curve, recall_score, classification_report

#Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.plotting import scatter_matrix

#Configure Visualization Defaults
#%matplotlib inline = show plots in Jupyter Notebook browser
# %matplotlib inline
mpl.style.use('ggplot')
sns.set_style('white')
pylab.rcParams['figure.figsize'] = 12,8
# Out:
# Python version: 3.7.13 (default, Mar 28 2022, 08:03:21) [MSC v.1916 64 bit (AMD64)]
# Pandas version: 1.3.5
# Matplotlib version: 3.5.3
# NumPy version: 1.21.5
# SciPy version: 1.7.3
# Scikit-learn version: 1.0.2
# IPython version: 7.34.0
# -------------------------

# %% [markdown]
# ## 1.2 Load DataSet from CSV

# %%
BANK_DATA_20C_DIR = "./Bank_Data_20C"
BANK_DATA_16C_DIR = "./Bank_Data_16C"
FILE_FULL = "bank-full.csv"
FILE_TEN_PERCENT = "bank.csv"

def print_verbose(info):
    print('-'*100)
    print(info)
    print()

data_20c = pd.read_csv(f"{BANK_DATA_20C_DIR}/{FILE_FULL}", sep=';')
data_16c = pd.read_csv(f"{BANK_DATA_16C_DIR}/{FILE_FULL}", sep=';')

# Use Full Bank Data with 20 features by default
data = data_20c

# %% [markdown]
# ## 1.3 Quick Look the Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# std        1.570960        0.578840       4.628198      1.734447     72.251528
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
data.describe(include=['O'])
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41188    41188              41188   41188   41188  41188     41188
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome      y
# count   41188       41188        41188  41188
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13769        8623        35563  36548

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 12

# %%
data.sample(10)
# Out:
#        age          job  marital          education  default housing loan  \
# 6144    37   technician   single  university.degree       no     yes  yes
# 18551   28     services  married        high.school       no      no   no
# 27193   57  blue-collar  married           basic.9y  unknown     yes   no
# 9747    31     services  married        high.school  unknown     yes   no
# 35945   27       admin.   single  university.degree       no      no   no
# 21801   32       admin.   single  university.degree       no      no   no
# 32495   33       admin.   single  university.degree       no     yes  yes
# 63      42  blue-collar  married           basic.6y  unknown      no   no
# 29649   55     services  married        high.school       no     yes  yes
# 34423   30      student  unknown           basic.9y       no      no   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 6144   telephone   may         tue  ...         1    999         0
# 18551   cellular   jul         thu  ...         1    999         0
# 27193   cellular   nov         fri  ...         7    999         1
# 9747   telephone   jun         mon  ...         2    999         0
# 35945   cellular   may         mon  ...         1    999         0
# 21801   cellular   aug         wed  ...         1    999         0
# 32495   cellular   may         fri  ...         3    999         1
# 63     telephone   may         mon  ...         1    999         0
# 29649   cellular   apr         mon  ...         1    999         0
# 34423   cellular   may         thu  ...         1    999         2
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 6144   nonexistent          1.1          93.994          -36.4      4.857
# 18551  nonexistent          1.4          93.918          -42.7      4.968
# 27193      failure         -0.1          93.200          -42.0      4.021
# 9747   nonexistent          1.4          94.465          -41.8      4.961
# 35945  nonexistent         -1.8          92.893          -46.2      1.264
# 21801  nonexistent          1.4          93.444          -36.1      4.964
# 32495      failure         -1.8          92.893          -46.2      1.313
# 63     nonexistent          1.1          93.994          -36.4      4.857
# 29649  nonexistent         -1.8          93.075          -47.1      1.405
# 34423      failure         -1.8          92.893          -46.2      1.266
#
#        nr.employed    y
# 6144        5191.0   no
# 18551       5228.1   no
# 27193       5195.8   no
# 9747        5228.1   no
# 35945       5099.1   no
# 21801       5228.1   no
# 32495       5099.1  yes
# 63          5191.0   no
# 29649       5099.1  yes
# 34423       5099.1   no
#
# [10 rows x 21 columns]

# %% [markdown]
# <a id="step2"></a>
# # 2. Step 2 - Exploratory Data Analysis

# %% [markdown]
# ## 2.1 Uni-Variable Distribution

# %% [markdown]
# ### 2.1.1 Categorical Features

# %%
def cat_visualize_bar(data, column):
    plt.figure(figsize=(8,4))
    ax=sns.countplot(x=column, data=data)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/len(data))
        x = p.get_x() + p.get_width()
        y = p.get_height()
        ax.annotate(percentage, (x, y),ha='center')
def cat_visualize_pie(data, column):
    percentages = (data[column].value_counts()/data.shape[0]*100)
    percentages_data, percentages_labels = list(percentages), list(percentages.index)
    plt.pie(percentages_data, labels=percentages_labels, autopct='%.1f%%')
    plt.title(f"`{column}` Percentage")
def cat_visualize_count_by_target(data, column):
    Y = data[column]
    total = len(Y)*1.
    ax=sns.countplot(x=column, data=data, hue='y')
    for p in ax.patches:
      ax.annotate('{:.1f}%'.format(100*p.get_height()/total), (p.get_x()+0.1, p.get_height()+5))
    ax.yaxis.set_ticks(np.linspace(0, total, 11))
    ax.set_yticklabels(map('{:.1f}%'.format, 100*ax.yaxis.get_majorticklocs()/total))
    ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %% [markdown]
# #### job

# %%
cat_visualize_pie(data, 'job')

# %%
cat_visualize_count_by_target(data, 'job')

# %% [markdown]
# #### marital

# %%
cat_visualize_pie(data, 'marital')

# %%
cat_visualize_count_by_target(data, 'marital')

# %% [markdown]
# #### education

# %%
cat_visualize_pie(data, 'education')

# %%
cat_visualize_count_by_target(data, 'education')

# %% [markdown]
# #### default

# %%
cat_visualize_pie(data, 'default')

# %%
cat_visualize_count_by_target(data, 'default')

# %% [markdown]
# #### housing

# %%
cat_visualize_pie(data, 'housing')

# %%
cat_visualize_count_by_target(data, 'housing')

# %% [markdown]
# #### loan

# %%
cat_visualize_pie(data, 'loan')

# %%
cat_visualize_count_by_target(data, 'loan')

# %% [markdown]
# #### contact

# %%
cat_visualize_pie(data, 'contact')

# %%
cat_visualize_count_by_target(data, 'contact')

# %% [markdown]
# #### month

# %%
cat_visualize_pie(data, 'month')

# %%
cat_visualize_count_by_target(data, 'month')

# %% [markdown]
# #### day_of_week

# %%
cat_visualize_pie(data, 'day_of_week')

# %%
cat_visualize_count_by_target(data, 'day_of_week')

# %% [markdown]
# #### poutcome

# %%
cat_visualize_pie(data, 'poutcome')

# %%
cat_visualize_count_by_target(data, 'poutcome')

# %% [markdown]
# #### target

# %%
cat_visualize_pie(data, 'y')

# %% [markdown]
# ### 2.1.2 Numerical Features

# %% [markdown]
# #### age

# %%
plt.figure(figsize=(8,4))
# sns.boxplot(x='age', y='y', data=data)
# fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
sns.boxplot(x='age', data=data)
fg=sns.FacetGrid(data=data, height=4, aspect=1.2)
fg.map(sns.histplot, 'age', bins=20)

# %% [markdown]
# #### duration

# %%
plt.figure(figsize=(8,4))
# sns.boxplot(x='duration', y='y', data=data)
# fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
sns.boxplot(x='duration', data=data)
fg=sns.FacetGrid(data=data, height=4, aspect=1.2)
fg.map(sns.distplot, 'duration')

# %% [markdown]
# #### campaign

# %%
# plt.figure(figsize=(8,4))
# sns.boxplot(x='campaign', y='y', data=data)
cat_visualize_pie(data, 'campaign')
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'campaign')

# %% [markdown]
# #### pdays

# %%
# plt.figure(figsize=(8,4))
# cat_visualize_pie(data, 'pdays') 
# sns.boxplot(x='pdays', y='y', data=data)
# fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
sns.boxplot(x='pdays', data=data)
fg=sns.FacetGrid(data=data, height=4, aspect=1.2)
fg.map(sns.distplot, 'pdays')

# %% [markdown]
# #### previous

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='previous', y='y', data=data)
# cat_visualize_pie(data, 'previous')
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'previous')

# %% [markdown]
# #### emp.var.rate

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='emp.var.rate', y='y', data=data)
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'emp.var.rate')

# %% [markdown]
# #### cons.price.idx

# %%
plt.figure(figsize=(8,4))
# sns.boxplot(x='cons.price.idx', y='y', data=data)
# fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
sns.boxplot(x='cons.price.idx',  data=data)
fg=sns.FacetGrid(data=data, height=4, aspect=1.2)
fg.map(sns.distplot, 'cons.price.idx')

# %% [markdown]
# #### cons.conf.idx

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='cons.conf.idx', y='y', data=data)
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'cons.conf.idx')

# %% [markdown]
# #### euribor3m

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='euribor3m', y='y', data=data)
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'euribor3m')

# %% [markdown]
# #### nr.employed

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='nr.employed', y='y', data=data)
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'nr.employed')

# %% [markdown]
# ## 2.2 Correlation Heatmap of Pair-Wise Features

# %%
def correlation_heatmap(data):
    _ , ax = plt.subplots(figsize =(14, 12))
    colormap = sns.diverging_palette(220, 10, as_cmap = True)
    
    _ = sns.heatmap(
        data.corr(), 
        cmap = colormap,
        square=True, 
        cbar_kws={'shrink':.9 }, 
        ax=ax,
        annot=True, 
        linewidths=0.1,vmax=1.0, linecolor='white',
        annot_kws={'fontsize':12 }
    )
    
    plt.title('Pearson Correlation of Features', y=1.05, size=15)

correlation_heatmap(data)

# %% [markdown]
# <a id="step3"></a>
# # 3. Step 3 - Data Wrangling
# Data Wrangling refers to the 4C process: Data Correcting, Completing, Creating and Converting.
# 1) Correcting aberrant values and outliers.
# 2) Completing missing information.
# 3) Creating new features for analysis.
# 4) Converting fields to the correct format for calculations and presentation.

# %%
# All Four Stages CONSTANT Parameters or Options
# Stage 1: Data Correcting: Directly drop dirty data
DROP_USELESS, USELESS_COLUMNS = True, ['month', 'day_of_week'] # possibly useless columns ['marital', 'month', 'day_of_week']
DROP_NOISY, NOISY_COLUMNS = True, ['default', 'pdays'] # possibly noisy columns ['default', 'pdays']: default with higher than 20% missing values, while pdays with too many outliers
DROP_UNPRACTICAL, UNPRACTICAL_COLUMNS = False, ['duration'] # remain if benchmark purpose, drop if practical use
# Stage 2: Data Completing: directly drop low-frequency rows with 'unknown' values in some columns rather than add some noise

# Stage 3: Data Creating
CREATE_COLUMNS = ['age']
# Stage 4: Data Converting: categorical featuers encoding and numercial features scaling
ENCODE_OPTION = 'label' # onehot or label encoding for categorical features
IF_SCALE = True # whether to scale or not
SCALE_OPTION = 'minmax' # minmax, robust or standard scaling for all numerical featuers

# %% [markdown]
# ## 3.1 Data Correcting
# In this stage, I will
# 1. drop ('marital', 'day_of_week', 'month') because these are useless features for prediting the target
# 2. drop ('default') because there are too many 'unknown' values (higher than 20%) in this column
# 3. drop ('duration') because in real-time practice there is no duration feature

# %%
data_corrected = data
drop_columns = []
if DROP_USELESS:
    drop_columns.extend(USELESS_COLUMNS)
if DROP_NOISY:
    drop_columns.extend(NOISY_COLUMNS)
if DROP_UNPRACTICAL:
    drop_unpractical.extend(UNPRACTICAL_COLUMNS)
data_corrected = data_corrected.drop(drop_columns, axis=1)
data_corrected = data_corrected.drop_duplicates()

# %%
data_corrected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41172 entries, 0 to 41187
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41172 non-null  int64
#  1   job             41172 non-null  object
#  2   marital         41172 non-null  object
#  3   education       41172 non-null  object
#  4   housing         41172 non-null  object
#  5   loan            41172 non-null  object
#  6   contact         41172 non-null  object
#  7   duration        41172 non-null  int64
#  8   campaign        41172 non-null  int64
#  9   previous        41172 non-null  int64
#  10  poutcome        41172 non-null  object
#  11  emp.var.rate    41172 non-null  float64
#  12  cons.price.idx  41172 non-null  float64
#  13  cons.conf.idx   41172 non-null  float64
#  14  euribor3m       41172 non-null  float64
#  15  nr.employed     41172 non-null  float64
#  16  y               41172 non-null  object
# dtypes: float64(5), int64(4), object(8)
# memory usage: 5.7+ MB

# %%
data_corrected.describe(include=['number'])
# Out:
#                 age      duration      campaign      previous  emp.var.rate  \
# count  41172.000000  41172.000000  41172.000000  41172.000000  41172.000000
# mean      40.023365    258.331317      2.568032      0.173030      0.081808
# std       10.420784    259.312967      2.770410      0.494985      1.570916
# min       17.000000      0.000000      1.000000      0.000000     -3.400000
# 25%       32.000000    102.000000      1.000000      0.000000     -1.800000
# 50%       38.000000    180.000000      2.000000      0.000000      1.100000
# 75%       47.000000    319.000000      3.000000      0.000000      1.400000
# max       98.000000   4918.000000     56.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    41172.000000   41172.000000  41172.000000  41172.000000
# mean        93.575706     -40.503276      3.621168   5167.030739
# std          0.578859       4.627895      1.734475     72.253427
# min         92.201000     -50.800000      0.634000   4963.600000
# 25%         93.075000     -42.700000      1.344000   5099.100000
# 50%         93.749000     -41.800000      4.857000   5191.000000
# 75%         93.994000     -36.400000      4.961000   5228.100000
# max         94.767000     -26.900000      5.045000   5228.100000

# %%
data_corrected.describe(include=['object', 'category'])
# Out:
#            job  marital          education housing   loan   contact  \
# count    41172    41172              41172   41172  41172     41172
# unique      12        4                  8       3      3         2
# top     admin.  married  university.degree     yes     no  cellular
# freq     10418    24917              12163   21569  33934     26133
#
#            poutcome      y
# count         41172  41172
# unique            3      2
# top     nonexistent     no
# freq          35547  36533

# %%
data_corrected.sample(10)
# Out:
#        age          job   marital            education housing loan  \
# 23166   32       admin.  divorced    university.degree      no   no
# 7486    31     services   married          high.school      no   no
# 40236   56     services   married          high.school     yes   no
# 35682   43  blue-collar   married             basic.4y      no   no
# 11915   33  blue-collar   married             basic.9y      no   no
# 26734   31   technician   married          high.school     yes  yes
# 6108    34  blue-collar   married             basic.9y      no   no
# 25697   38  blue-collar   married  professional.course     yes  yes
# 23788   41       admin.   married    university.degree     yes   no
# 3230    30   management   married    university.degree      no   no
#
#          contact  duration  campaign  previous     poutcome  emp.var.rate  \
# 23166   cellular        74         2         0  nonexistent           1.4
# 7486   telephone      1269         1         0  nonexistent           1.1
# 40236   cellular       427         2         1      failure          -1.7
# 35682   cellular       465         2         0  nonexistent          -1.8
# 11915  telephone         8        13         0  nonexistent           1.4
# 26734   cellular       435         1         0  nonexistent          -0.1
# 6108   telephone        59         1         0  nonexistent           1.1
# 25697   cellular        87         2         0  nonexistent          -0.1
# 23788   cellular        47        13         0  nonexistent           1.4
# 3230   telephone       221         2         0  nonexistent           1.1
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 23166          93.444          -36.1      4.965       5228.1   no
# 7486           93.994          -36.4      4.864       5191.0  yes
# 40236          94.215          -40.3      0.884       4991.6   no
# 35682          92.893          -46.2      1.244       5099.1   no
# 11915          94.465          -41.8      4.959       5228.1   no
# 26734          93.200          -42.0      4.076       5195.8   no
# 6108           93.994          -36.4      4.857       5191.0   no
# 25697          93.200          -42.0      4.120       5195.8   no
# 23788          93.444          -36.1      4.963       5228.1   no
# 3230           93.994          -36.4      4.860       5191.0   no

# %%
data_corrected.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# housing           0
# loan              0
# contact           0
# duration          0
# campaign          0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data_corrected.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 3.2 Data Completing
# There are no explicit missing values for numerical features, but there are implicit missing values for categorical features after dropping ('poutcome', 'default'):
# - job: 'unknown' 0.8%
# - marital: 'unknown': 0.2%
# - education: 'unknown' 4.2%
# - housing: 'unknown' 2.4%
# - loan: 'unknown' 2.4%

# %% [markdown]
# As we cannot simply fill these 'unknown' values with most frequent values, we can simply drop these rows because these valus account not so much.

# %%
data_completed = data_corrected.copy()
cat_columns = list(data_completed.select_dtypes(include=['object']).columns)
for column in cat_columns:
    data_completed = data_completed.drop(data_completed[data_completed[column]=='unknown'].index)

# %%
data_completed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38230 entries, 0 to 41187
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             38230 non-null  int64
#  1   job             38230 non-null  object
#  2   marital         38230 non-null  object
#  3   education       38230 non-null  object
#  4   housing         38230 non-null  object
#  5   loan            38230 non-null  object
#  6   contact         38230 non-null  object
#  7   duration        38230 non-null  int64
#  8   campaign        38230 non-null  int64
#  9   previous        38230 non-null  int64
#  10  poutcome        38230 non-null  object
#  11  emp.var.rate    38230 non-null  float64
#  12  cons.price.idx  38230 non-null  float64
#  13  cons.conf.idx   38230 non-null  float64
#  14  euribor3m       38230 non-null  float64
#  15  nr.employed     38230 non-null  float64
#  16  y               38230 non-null  object
# dtypes: float64(5), int64(4), object(8)
# memory usage: 6.3+ MB

# %%
data_completed.describe(include=['number'])
# Out:
#                 age      duration      campaign      previous  emp.var.rate  \
# count  38230.000000  38230.000000  38230.000000  38230.000000  38230.000000
# mean      39.859953    258.252969      2.567094      0.170076      0.082812
# std       10.288796    259.827170      2.767875      0.487253      1.565890
# min       17.000000      0.000000      1.000000      0.000000     -3.400000
# 25%       32.000000    102.000000      1.000000      0.000000     -1.800000
# 50%       38.000000    180.000000      2.000000      0.000000      1.100000
# 75%       47.000000    319.000000      3.000000      0.000000      1.400000
# max       98.000000   4918.000000     43.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    38230.000000   38230.000000  38230.000000  38230.000000
# mean        93.570365     -40.541964      3.623202   5167.428750
# std          0.576382       4.622818      1.730244     71.761949
# min         92.201000     -50.800000      0.634000   4963.600000
# 25%         93.075000     -42.700000      1.344000   5099.100000
# 50%         93.444000     -41.800000      4.857000   5191.000000
# 75%         93.994000     -36.400000      4.961000   5228.100000
# max         94.767000     -26.900000      5.045000   5228.100000

# %%
data_completed.describe(include=['object', 'category'])
# Out:
#            job  marital          education housing   loan   contact  \
# count    38230    38230              38230   38230  38230     38230
# unique      11        3                  7       2      2         2
# top     admin.  married  university.degree     yes     no  cellular
# freq      9933    23173              11816   20571  32271     24430
#
#            poutcome      y
# count         38230  38230
# unique            3      2
# top     nonexistent     no
# freq          33051  33973

# %%
data_completed.sample(10)
# Out:
#        age          job   marital            education housing loan  \
# 4817    40       admin.    single          high.school     yes   no
# 27575   56   unemployed   married             basic.9y     yes  yes
# 4329    36       admin.  divorced          high.school     yes  yes
# 39256   38    housemaid    single          high.school     yes   no
# 10762   30  blue-collar   married             basic.4y      no   no
# 13111   52      retired   married  professional.course     yes   no
# 30489   52       admin.    single          high.school      no   no
# 36724   29   technician   married          high.school      no   no
# 9079    32    housemaid   married          high.school      no   no
# 24301   46   technician   married  professional.course     yes   no
#
#          contact  duration  campaign  previous     poutcome  emp.var.rate  \
# 4817   telephone       738         3         0  nonexistent           1.1
# 27575   cellular       322         2         0  nonexistent          -0.1
# 4329   telephone       124         1         0  nonexistent           1.1
# 39256   cellular       422         1         1      success          -1.8
# 10762  telephone        89         4         0  nonexistent           1.4
# 13111   cellular        53         3         0  nonexistent           1.4
# 30489   cellular       127         2         0  nonexistent          -1.8
# 36724   cellular       157         2         0  nonexistent          -2.9
# 9079   telephone       372         1         0  nonexistent           1.4
# 24301   cellular        61         1         1      failure          -0.1
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 4817           93.994          -36.4      4.858       5191.0   no
# 27575          93.200          -42.0      4.021       5195.8   no
# 4329           93.994          -36.4      4.856       5191.0   no
# 39256          93.369          -34.8      0.649       5008.7  yes
# 10762          94.465          -41.8      4.961       5228.1   no
# 13111          93.918          -42.7      4.962       5228.1   no
# 30489          92.893          -46.2      1.354       5099.1   no
# 36724          92.963          -40.8      1.268       5076.2  yes
# 9079           94.465          -41.8      4.866       5228.1   no
# 24301          93.200          -42.0      4.191       5195.8   no

# %%
data_completed.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# housing           0
# loan              0
# contact           0
# duration          0
# campaign          0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data_completed.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 3.3 Data Creating
# 'age' feature need to be quantized into discrete bins to create new 'age_period' feature:

# %%
data_created = data_completed.copy()
for column in CREATE_COLUMNS:
    if column == 'age':
        data_created.insert(0, 'age_period', pd.cut(data_completed['age'].astype(int), 5))
        data_created = data_created.drop('age', axis=1)
data_created = data_created.drop_duplicates()

# %%
data_created.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38184 entries, 0 to 41187
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age_period      38184 non-null  category
#  1   job             38184 non-null  object
#  2   marital         38184 non-null  object
#  3   education       38184 non-null  object
#  4   housing         38184 non-null  object
#  5   loan            38184 non-null  object
#  6   contact         38184 non-null  object
#  7   duration        38184 non-null  int64
#  8   campaign        38184 non-null  int64
#  9   previous        38184 non-null  int64
#  10  poutcome        38184 non-null  object
#  11  emp.var.rate    38184 non-null  float64
#  12  cons.price.idx  38184 non-null  float64
#  13  cons.conf.idx   38184 non-null  float64
#  14  euribor3m       38184 non-null  float64
#  15  nr.employed     38184 non-null  float64
#  16  y               38184 non-null  object
# dtypes: category(1), float64(5), int64(3), object(8)
# memory usage: 5.0+ MB

# %%
data_created.describe(include=['number'])
# Out:
#            duration      campaign      previous  emp.var.rate  cons.price.idx  \
# count  38184.000000  38184.000000  38184.000000  38184.000000    38184.000000
# mean     258.394537      2.568510      0.170281      0.081851       93.570153
# std      259.936448      2.769151      0.487511      1.566167        0.576535
# min        0.000000      1.000000      0.000000     -3.400000       92.201000
# 25%      102.000000      1.000000      0.000000     -1.800000       93.075000
# 50%      180.000000      2.000000      0.000000      1.100000       93.444000
# 75%      320.000000      3.000000      0.000000      1.400000       93.994000
# max     4918.000000     43.000000      7.000000      1.400000       94.767000
#
#        cons.conf.idx     euribor3m   nr.employed
# count   38184.000000  38184.000000  38184.000000
# mean      -40.544657      3.622147   5167.394301
# std         4.623556      1.730559     71.778700
# min       -50.800000      0.634000   4963.600000
# 25%       -42.700000      1.344000   5099.100000
# 50%       -41.800000      4.857000   5191.000000
# 75%       -36.400000      4.961000   5228.100000
# max       -26.900000      5.045000   5228.100000

# %%
data_created.describe(include=['category', 'object'])
# Out:
#           age_period     job  marital          education housing   loan  \
# count          38184   38184    38184              38184   38184  38184
# unique             5      11        3                  7       2      2
# top     (33.2, 49.4]  admin.  married  university.degree     yes     no
# freq           18723    9914    23134              11799   20548  32227
#
#          contact     poutcome      y
# count      38184        38184  38184
# unique         2            3      2
# top     cellular  nonexistent     no
# freq       24406        33005  33927

# %%
data_created.sample(10)
# Out:
#            age_period            job   marital            education housing  \
# 10573    (33.2, 49.4]         admin.   married    university.degree     yes
# 20882  (16.919, 33.2]         admin.    single    university.degree      no
# 27167    (49.4, 65.6]         admin.    single    university.degree      no
# 13993  (16.919, 33.2]    blue-collar    single             basic.9y      no
# 7827     (33.2, 49.4]         admin.  divorced    university.degree     yes
# 12882  (16.919, 33.2]     technician    single  professional.course     yes
# 40752  (16.919, 33.2]     technician    single    university.degree     yes
# 6206   (16.919, 33.2]  self-employed    single    university.degree      no
# 19692  (16.919, 33.2]         admin.  divorced    university.degree     yes
# 13245  (16.919, 33.2]         admin.    single    university.degree     yes
#
#       loan    contact  duration  campaign  previous     poutcome  \
# 10573   no  telephone        43         9         0  nonexistent
# 20882  yes   cellular       103         1         0  nonexistent
# 27167  yes   cellular       143         1         0  nonexistent
# 13993   no   cellular       187         2         0  nonexistent
# 7827    no  telephone       144         2         0  nonexistent
# 12882   no   cellular       154         1         0  nonexistent
# 40752   no   cellular       463         1         0  nonexistent
# 6206    no  telephone       518         2         0  nonexistent
# 19692   no  telephone       262         7         0  nonexistent
# 13245  yes   cellular       143         1         0  nonexistent
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 10573           1.4          94.465          -41.8      4.961       5228.1
# 20882           1.4          93.444          -36.1      4.964       5228.1
# 27167          -0.1          93.200          -42.0      4.021       5195.8
# 13993           1.4          93.918          -42.7      4.963       5228.1
# 7827            1.4          94.465          -41.8      4.865       5228.1
# 12882           1.4          93.918          -42.7      4.962       5228.1
# 40752          -1.1          94.199          -37.5      0.879       4963.6
# 6206            1.1          93.994          -36.4      4.857       5191.0
# 19692           1.4          93.444          -36.1      4.968       5228.1
# 13245           1.4          93.918          -42.7      4.962       5228.1
#
#          y
# 10573   no
# 20882   no
# 27167   no
# 13993   no
# 7827    no
# 12882   no
# 40752  yes
# 6206    no
# 19692   no
# 13245   no

# %%
data_created.isnull().sum()
# Out:
# age_period        0
# job               0
# marital           0
# education         0
# housing           0
# loan              0
# contact           0
# duration          0
# campaign          0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data_created.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 3.4 Data Converting
# There are several categorical object features(age_period, job, education, housing, loan and contact) need to be labeled:
# - age_period: (0-16.919, 16.919-33.2, 33.2-49.4, 49.4-65.6, 65.6-98.0)
# - job: ('admin', 'blue-collar', 'technician', 'services', 'management', 'retired', 'entrepreneur', 'self-employed', 'housemaid', 'unemployed', 'student')
# - marital: ('married', 'single', 'divorced')
# - education: ('university.degree', 'high.school', 'basic.9y', 'professional.course', 'basic.4y', 'basic.6y', 'illiterate')
# - housing ('yes', 'no')
# - loan ('yes', 'no')
# - contact ('cellular', 'telephone')
# - target ('yes', 'no')
# - month ('jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'dec', 'nov', 'dec')
# - day_of_week ('mon', 'tue', 'wed', 'thu', 'fri')

# %%
data_converted = data_created.copy()
cat_columns = list(data_converted.select_dtypes(include=['object']).columns)
cat_columns.remove('y')
encoder = LabelEncoder()

# age_period => age_period_code
data_converted['age_period_code'] = encoder.fit_transform(data_converted['age_period'])
data_converted = data_converted.drop(['age_period'], axis=1)

# y => target: yes => 1, no => 0
data_converted['target'] = encoder.fit_transform(data_converted['y'])
data_converted = data_converted.drop(['y'], axis=1)

# encode remaining categorical columns
if ENCODE_OPTION == 'onehot':
    data_converted = pd.get_dummies(data_converted)
else:
    for column in cat_columns:
        data_converted[f"{column}_code"] = encoder.fit_transform(data_converted[column])
        data_converted = data_converted.drop([column], axis=1)
    
# Scale and Normalize
if IF_SCALE:
    if SCALE_OPTION == 'minmax':
        scaler = MinMaxScaler()
    elif SCALE_OPTION == 'standard':
        scaler = StandardScaler()
    else:
        scaler = RobustScaler()
    num_columns = list(data_converted.select_dtypes(include=['number']).columns)
    for column in num_columns:
        data_converted[column] = pd.DataFrame(scaler.fit_transform(pd.DataFrame(data_converted[column])), index=data_converted.index, columns=[column])

# %%
data_converted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38184 entries, 0 to 41187
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   duration         38184 non-null  float64
#  1   campaign         38184 non-null  float64
#  2   previous         38184 non-null  float64
#  3   emp.var.rate     38184 non-null  float64
#  4   cons.price.idx   38184 non-null  float64
#  5   cons.conf.idx    38184 non-null  float64
#  6   euribor3m        38184 non-null  float64
#  7   nr.employed      38184 non-null  float64
#  8   age_period_code  38184 non-null  float64
#  9   target           38184 non-null  float64
#  10  job_code         38184 non-null  float64
#  11  marital_code     38184 non-null  float64
#  12  education_code   38184 non-null  float64
#  13  housing_code     38184 non-null  float64
#  14  loan_code        38184 non-null  float64
#  15  contact_code     38184 non-null  float64
#  16  poutcome_code    38184 non-null  float64
# dtypes: float64(17)
# memory usage: 5.2 MB

# %%
data_converted.describe(include=['number'])
# Out:
#            duration      campaign      previous  emp.var.rate  cons.price.idx  \
# count  38184.000000  38184.000000  38184.000000  38184.000000    38184.000000
# mean       0.052541      0.037345      0.024326      0.725386        0.533575
# std        0.052854      0.065932      0.069644      0.326285        0.224682
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%        0.020740      0.000000      0.000000      0.333333        0.340608
# 50%        0.036600      0.023810      0.000000      0.937500        0.484412
# 75%        0.065067      0.047619      0.000000      1.000000        0.698753
# max        1.000000      1.000000      1.000000      1.000000        1.000000
#
#        cons.conf.idx     euribor3m   nr.employed  age_period_code  \
# count   38184.000000  38184.000000  38184.000000     38184.000000
# mean        0.429094      0.677431      0.770489         0.221474
# std         0.193454      0.392328      0.271375         0.185472
# min         0.000000      0.000000      0.000000         0.000000
# 25%         0.338912      0.160961      0.512287         0.000000
# 50%         0.376569      0.957379      0.859735         0.250000
# 75%         0.602510      0.980957      1.000000         0.250000
# max         1.000000      1.000000      1.000000         1.000000
#
#              target      job_code  marital_code  education_code  housing_code  \
# count  38184.000000  38184.000000  38184.000000    38184.000000  38184.000000
# mean       0.111486      0.365417      0.584433        0.601967      0.538131
# std        0.314738      0.355536      0.302340        0.344259      0.498550
# min        0.000000      0.000000      0.000000        0.000000      0.000000
# 25%        0.000000      0.000000      0.500000        0.333333      0.000000
# 50%        0.000000      0.200000      0.500000        0.500000      1.000000
# 75%        0.000000      0.700000      1.000000        1.000000      1.000000
# max        1.000000      1.000000      1.000000        1.000000      1.000000
#
#           loan_code  contact_code  poutcome_code
# count  38184.000000  38184.000000   38184.000000
# mean       0.156008      0.360832       0.464737
# std        0.362867      0.480248       0.180736
# min        0.000000      0.000000       0.000000
# 25%        0.000000      0.000000       0.500000
# 50%        0.000000      0.000000       0.500000
# 75%        0.000000      1.000000       0.500000
# max        1.000000      1.000000       1.000000

# %%
data_converted.sample(10)
# Out:
#        duration  campaign  previous  emp.var.rate  cons.price.idx  \
# 9180   0.004880  0.000000  0.000000      1.000000        0.882307
# 19385  0.035584  0.000000  0.000000      1.000000        0.484412
# 10958  0.029687  0.047619  0.000000      1.000000        0.882307
# 8481   0.024400  0.238095  0.000000      1.000000        0.882307
# 1095   0.014843  0.023810  0.000000      0.937500        0.698753
# 21557  0.031517  0.023810  0.000000      1.000000        0.484412
# 37511  0.015250  0.000000  0.142857      0.104167        0.000000
# 38294  0.013827  0.000000  0.000000      0.000000        0.089634
# 332    0.035380  0.095238  0.000000      0.937500        0.698753
# 9334   0.011793  0.000000  0.000000      1.000000        0.882307
#
#        cons.conf.idx  euribor3m  nr.employed  age_period_code  target  \
# 9180        0.376569   0.982317     1.000000             0.25     0.0
# 19385       0.615063   0.982317     1.000000             0.25     0.0
# 10958       0.376569   0.981183     1.000000             0.25     0.0
# 8481        0.376569   0.958966     1.000000             0.25     0.0
# 1095        0.602510   0.957153     0.859735             0.00     0.0
# 21557       0.615063   0.981410     1.000000             0.00     0.0
# 37511       0.811715   0.054183     0.425709             0.25     0.0
# 38294       1.000000   0.024484     0.203781             0.25     0.0
# 332         0.602510   0.957379     0.859735             0.25     0.0
# 9334        0.376569   0.982317     1.000000             0.25     0.0
#
#        job_code  marital_code  education_code  housing_code  loan_code  \
# 9180        0.7           0.5        0.833333           0.0        0.0
# 19385       0.9           1.0        0.833333           0.0        1.0
# 10958       0.1           0.5        0.000000           0.0        0.0
# 8481        0.0           0.5        1.000000           1.0        0.0
# 1095        0.1           0.5        0.333333           0.0        0.0
# 21557       0.9           0.5        0.500000           1.0        0.0
# 37511       0.1           0.5        0.333333           0.0        0.0
# 38294       0.9           0.5        1.000000           1.0        0.0
# 332         0.4           0.5        0.500000           1.0        0.0
# 9334        0.1           0.5        0.500000           0.0        0.0
#
#        contact_code  poutcome_code
# 9180            1.0            0.5
# 19385           0.0            0.5
# 10958           1.0            0.5
# 8481            1.0            0.5
# 1095            1.0            0.5
# 21557           0.0            0.5
# 37511           0.0            0.0
# 38294           0.0            0.5
# 332             1.0            0.5
# 9334            1.0            0.5

# %%
data_converted.isnull().sum()
# Out:
# duration           0
# campaign           0
# previous           0
# emp.var.rate       0
# cons.price.idx     0
# cons.conf.idx      0
# euribor3m          0
# nr.employed        0
# age_period_code    0
# target             0
# job_code           0
# marital_code       0
# education_code     0
# housing_code       0
# loan_code          0
# contact_code       0
# poutcome_code      0
# dtype: int64

# %%
data_converted.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <a id="step4"></a>
# # 4. Step 4 - Data Modeling with Machine Learning

# %% [markdown]
# ## 4.1 Features&Target Split and Modeling Options Definition

# %%
data_cleaned = data_converted.copy()
x_columns = list(data_cleaned.columns)
x_columns.remove('target')
y_columns = ['target']
data_cleaned_x = data_cleaned[x_columns]
data_cleaned_y = data_cleaned[y_columns]

ALGS = [
    #GLM
    linear_model.LogisticRegressionCV(),
    linear_model.SGDClassifier(),
    linear_model.Perceptron(),
    
    #Nearest Neighbor
    neighbors.KNeighborsClassifier(),
    
    #Navies Bayes
    naive_bayes.BernoulliNB(),
    naive_bayes.GaussianNB(),
    
    #Trees    
    tree.DecisionTreeClassifier(),
    
    #SVM
    svm.LinearSVC(),
    svm.SVC(probability=True),
    
    # Ensemble Models
    ensemble.BaggingClassifier(),
    ensemble.RandomForestClassifier(),
    ensemble.AdaBoostClassifier(),
    XGBClassifier(),
    LGBMClassifier(),
    CatBoostClassifier(verbose=False),
]

CV_TRAIN_SIZE, CV_TEST_SIZE, N_SPLITS, RANDOM_STATE = 0.6, 0.3, 10, 4326
# run model 10x with 60/30 split intentionally leaving out 10%
CV_SPLIT = model_selection.ShuffleSplit(n_splits=N_SPLITS, train_size=CV_TRAIN_SIZE, test_size=CV_TEST_SIZE, random_state=RANDOM_STATE) 

def algs_benchmark(data_x, data_y, algs, cv_split):
    MLA_columns = ['MLA Name', 'MLA Parameters','MLA Train Accuracy Mean', 'MLA Test Accuracy Mean', 'MLA Test Accuracy 3*STD' ,'MLA Time']
    MLA_compare = pd.DataFrame(columns=MLA_columns)
    row_index = 0
    
    for alg in algs:
        MLA_name = alg.__class__.__name__
        print(f"==> {MLA_name} Modeling...")
        cv_results = model_selection.cross_validate(alg, data_x.copy(), data_y.copy(), cv=cv_split, return_train_score=True)
        
        MLA_compare.loc[row_index, 'MLA Name'] = MLA_name
        MLA_compare.loc[row_index, 'MLA Parameters'] = str(alg.get_params())
        MLA_compare.loc[row_index, 'MLA Time'] = cv_results['fit_time'].mean()
        MLA_compare.loc[row_index, 'MLA Train Accuracy Mean'] = cv_results['train_score'].mean()
        MLA_compare.loc[row_index, 'MLA Test Accuracy Mean'] = cv_results['test_score'].mean()   
        MLA_compare.loc[row_index, 'MLA Test Accuracy 3*STD'] = cv_results['test_score'].std()*3
        print(f"Train Accuracy Mean: {cv_results['train_score'].mean()}, Test Accuracy Mean: {cv_results['test_score'].mean()}")
        row_index+=1
        
    MLA_compare.sort_values(by=['MLA Test Accuracy Mean'], ascending=False, inplace=True)
    return MLA_compare

def visualize_algs_benchmark_results(algs_benchmark_results):
    sns.barplot(x='MLA Test Accuracy Mean', y='MLA Name', data=algs_benchmark_results, color='g')
    plt.title('Machine Learning Algorithm Accuracy Score \n')
    plt.xlabel('Accuracy Score (%)')
    plt.ylabel('Algorithm')

# %%
data_cleaned[x_columns].info()
data_cleaned[x_columns].sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38184 entries, 0 to 41187
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   duration         38184 non-null  float64
#  1   campaign         38184 non-null  float64
#  2   previous         38184 non-null  float64
#  3   emp.var.rate     38184 non-null  float64
#  4   cons.price.idx   38184 non-null  float64
#  5   cons.conf.idx    38184 non-null  float64
#  6   euribor3m        38184 non-null  float64
#  7   nr.employed      38184 non-null  float64
#  8   age_period_code  38184 non-null  float64
#  9   job_code         38184 non-null  float64
#  10  marital_code     38184 non-null  float64
#  11  education_code   38184 non-null  float64
#  12  housing_code     38184 non-null  float64
#  13  loan_code        38184 non-null  float64
#  14  contact_code     38184 non-null  float64
#  15  poutcome_code    38184 non-null  float64
# dtypes: float64(16)
# memory usage: 5.0 MB
#        duration  campaign  previous  emp.var.rate  cons.price.idx  \
# 40660  0.168768  0.023810  0.000000      0.479167        0.778644
# 39252  0.034364  0.047619  0.142857      0.333333        0.455183
# 1566   0.077064  0.071429  0.000000      0.937500        0.698753
# 16113  0.038227  0.095238  0.000000      1.000000        0.669135
# 27974  0.070150  0.000000  0.000000      0.333333        0.340608
# 13529  0.044124  0.000000  0.000000      1.000000        0.669135
# 3885   0.020943  0.142857  0.000000      0.937500        0.698753
# 33943  0.036397  0.000000  0.000000      0.333333        0.269680
# 16517  0.078691  0.000000  0.000000      1.000000        0.669135
# 9294   0.085807  0.095238  0.000000      1.000000        0.882307
#
#        cons.conf.idx  euribor3m  nr.employed  age_period_code  job_code  \
# 40660       0.556485   0.055770     0.000000             0.00       0.1
# 39252       0.669456   0.003401     0.170510             0.00       0.7
# 1566        0.602510   0.956926     0.859735             0.25       0.0
# 16113       0.338912   0.980957     1.000000             0.00       0.1
# 27974       0.154812   0.195874     0.512287             0.25       0.6
# 13529       0.338912   0.981410     1.000000             0.25       0.1
# 3885        0.602510   0.957833     0.859735             0.00       0.8
# 33943       0.192469   0.146679     0.512287             0.00       0.1
# 16517       0.338912   0.981410     1.000000             0.50       1.0
# 9294        0.376569   0.982317     1.000000             0.00       0.4
#
#        marital_code  education_code  housing_code  loan_code  contact_code  \
# 40660           0.5        0.000000           0.0        0.0           0.0
# 39252           1.0        0.833333           1.0        0.0           0.0
# 1566            0.5        1.000000           1.0        0.0           1.0
# 16113           1.0        0.166667           0.0        0.0           0.0
# 27974           0.5        0.500000           1.0        0.0           0.0
# 13529           0.5        0.333333           1.0        0.0           0.0
# 3885            1.0        0.500000           1.0        1.0           1.0
# 33943           1.0        0.333333           1.0        1.0           0.0
# 16517           0.5        1.000000           1.0        0.0           0.0
# 9294            0.5        1.000000           1.0        0.0           1.0
#
#        poutcome_code
# 40660            0.5
# 39252            0.0
# 1566             0.5
# 16113            0.5
# 27974            0.5
# 13529            0.5
# 3885             0.5
# 33943            0.5
# 16517            0.5
# 9294             0.5

# %%
data_cleaned[y_columns].info()
data_cleaned[y_columns].sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38184 entries, 0 to 41187
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  38184 non-null  float64
# dtypes: float64(1)
# memory usage: 596.6 KB
#        target
# 23698     0.0
# 18853     0.0
# 4081      0.0
# 32673     0.0
# 11125     0.0
# 38497     0.0
# 25945     0.0
# 34821     0.0
# 31412     0.0
# 31373     0.0

# %% [markdown]
# ## 4.2 Data Modeling by Machine Learning Algorithms, Get and Visualize Benchmark Results

# %%
algs_benchmark_results = algs_benchmark(data_cleaned_x, data_cleaned_y, ALGS, CV_SPLIT)
algs_benchmark_results
# Out:
# ==> LogisticRegressionCV Modeling...
# Train Accuracy Mean: 0.9094762112614578, Test Accuracy Mean: 0.9103701117318437
# ==> SGDClassifier Modeling...
# Train Accuracy Mean: 0.904687909209952, Test Accuracy Mean: 0.9054905726256983
# ==> Perceptron Modeling...
# Train Accuracy Mean: 0.8646922741161065, Test Accuracy Mean: 0.8654504189944134
# ==> KNeighborsClassifier Modeling...
# Train Accuracy Mean: 0.9172806634657356, Test Accuracy Mean: 0.8952426675977654
# ==> BernoulliNB Modeling...
# Train Accuracy Mean: 0.8879528590135312, Test Accuracy Mean: 0.8890450418994413
# ==> GaussianNB Modeling...
# Train Accuracy Mean: 0.8334439109559144, Test Accuracy Mean: 0.8338687150837988
# ==> DecisionTreeClassifier Modeling...
# Train Accuracy Mean: 1.0, Test Accuracy Mean: 0.8880848463687151
# ==> LinearSVC Modeling...
# Train Accuracy Mean: 0.9076516804888695, Test Accuracy Mean: 0.9087028631284916
# ==> SVC Modeling...
# Train Accuracy Mean: 0.9043998254037537, Test Accuracy Mean: 0.9030289804469274
# ==> BaggingClassifier Modeling...
# Train Accuracy Mean: 0.9930336097773897, Test Accuracy Mean: 0.9074022346368714
# ==> RandomForestClassifier Modeling...
# Train Accuracy Mean: 0.9999781754692274, Test Accuracy Mean: 0.9132419692737429
# ==> AdaBoostClassifier Modeling...
# Train Accuracy Mean: 0.9096508075076386, Test Accuracy Mean: 0.9112430167597765
# ==> XGBClassifier Modeling...
# Train Accuracy Mean: 0.9637363596682672, Test Accuracy Mean: 0.914036312849162
# ==> LGBMClassifier Modeling...
# Train Accuracy Mean: 0.9427891750327368, Test Accuracy Mean: 0.9172398743016761
# ==> CatBoostClassifier Modeling...
# Train Accuracy Mean: 0.9529026625927542, Test Accuracy Mean: 0.9167859636871507
#                   MLA Name                                     MLA Parameters  \
# 13          LGBMClassifier  {'boosting_type': 'gbdt', 'class_weight': None...
# 14      CatBoostClassifier                                 {'verbose': False}
# 12           XGBClassifier  {'objective': 'binary:logistic', 'use_label_en...
# 10  RandomForestClassifier  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# 11      AdaBoostClassifier  {'algorithm': 'SAMME.R', 'base_estimator': Non...
# 0     LogisticRegressionCV  {'Cs': 10, 'class_weight': None, 'cv': None, '...
# 7                LinearSVC  {'C': 1.0, 'class_weight': None, 'dual': True,...
# 9        BaggingClassifier  {'base_estimator': None, 'bootstrap': True, 'b...
# 1            SGDClassifier  {'alpha': 0.0001, 'average': False, 'class_wei...
# 8                      SVC  {'C': 1.0, 'break_ties': False, 'cache_size': ...
# 3     KNeighborsClassifier  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 4              BernoulliNB  {'alpha': 1.0, 'binarize': 0.0, 'class_prior':...
# 6   DecisionTreeClassifier  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 2               Perceptron  {'alpha': 0.0001, 'class_weight': None, 'early...
# 5               GaussianNB           {'priors': None, 'var_smoothing': 1e-09}
#
#    MLA Train Accuracy Mean MLA Test Accuracy Mean MLA Test Accuracy 3*STD  \
# 13                0.942789                0.91724                0.004936
# 14                0.952903               0.916786                0.005364
# 12                0.963736               0.914036                0.008474
# 10                0.999978               0.913242                0.006326
# 11                0.909651               0.911243                0.007564
# 0                 0.909476                0.91037                0.003942
# 7                 0.907652               0.908703                0.005764
# 9                 0.993034               0.907402                0.007082
# 1                 0.904688               0.905491                0.005082
# 8                   0.9044               0.903029                0.008198
# 3                 0.917281               0.895243                0.007765
# 4                 0.887953               0.889045                0.007768
# 6                      1.0               0.888085                0.011393
# 2                 0.864692                0.86545                0.127614
# 5                 0.833444               0.833869                0.009151
#
#      MLA Time
# 13   0.117665
# 14   6.884614
# 12   0.568624
# 10   1.389262
# 11    0.53977
# 0    0.989403
# 7    0.189831
# 9    0.431469
# 1    0.026272
# 8   25.284049
# 3    0.008817
# 4    0.014033
# 6    0.072655
# 2     0.01995
# 5    0.012347

# %%
visualize_algs_benchmark_results(algs_benchmark_results)

# %%
TEST_SIZE = 0.30
data_cleaned_train_x, data_cleaned_test_x, data_cleaned_train_y, data_cleaned_test_y = model_selection.train_test_split(data_cleaned_x, data_cleaned_y, test_size=TEST_SIZE, random_state = 4262)
model = LGBMClassifier()
prams={
    'learning_rate':[0.01,0.03,0.05,0.1,0.15,0.2],
    'n_estimators':[100,200,500,1000,2000],
    'max_depth':[3,5,10],
    'colsample_bytree':[0.1,0.3,0.5,1],
    'subsample':[0.1,0.3,0.5,1]
}
random_model = RandomizedSearchCV(model, param_distributions=prams, verbose=10, n_iter=20, cv=5, scoring='accuracy')
random_model.fit(data_cleaned_train_x, data_cleaned_train_y)
print(random_model.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5; 1/20] START colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=1000, subsample=0.3
# [CV 1/5; 1/20] END colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=1000, subsample=0.3;, score=0.918 total time=   0.5s
# [CV 2/5; 1/20] START colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=1000, subsample=0.3
# [CV 2/5; 1/20] END colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=1000, subsample=0.3;, score=0.916 total time=   0.6s
# [CV 3/5; 1/20] START colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=1000, subsample=0.3
# [CV 3/5; 1/20] END colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=1000, subsample=0.3;, score=0.907 total time=   0.5s
# [CV 4/5; 1/20] START colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=1000, subsample=0.3
# [CV 4/5; 1/20] END colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=1000, subsample=0.3;, score=0.907 total time=   0.5s
# [CV 5/5; 1/20] START colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=1000, subsample=0.3
# [CV 5/5; 1/20] END colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=1000, subsample=0.3;, score=0.914 total time=   0.5s
# [CV 1/5; 2/20] START colsample_bytree=1, learning_rate=0.15, max_depth=10, n_estimators=500, subsample=1
# [CV 1/5; 2/20] END colsample_bytree=1, learning_rate=0.15, max_depth=10, n_estimators=500, subsample=1;, score=0.915 total time=   0.3s
# [CV 2/5; 2/20] START colsample_bytree=1, learning_rate=0.15, max_depth=10, n_estimators=500, subsample=1
# [CV 2/5; 2/20] END colsample_bytree=1, learning_rate=0.15, max_depth=10, n_estimators=500, subsample=1;, score=0.913 total time=   0.3s
# [CV 3/5; 2/20] START colsample_bytree=1, learning_rate=0.15, max_depth=10, n_estimators=500, subsample=1
# [CV 3/5; 2/20] END colsample_bytree=1, learning_rate=0.15, max_depth=10, n_estimators=500, subsample=1;, score=0.909 total time=   0.3s
# [CV 4/5; 2/20] START colsample_bytree=1, learning_rate=0.15, max_depth=10, n_estimators=500, subsample=1
# [CV 4/5; 2/20] END colsample_bytree=1, learning_rate=0.15, max_depth=10, n_estimators=500, subsample=1;, score=0.909 total time=   0.3s
# [CV 5/5; 2/20] START colsample_bytree=1, learning_rate=0.15, max_depth=10, n_estimators=500, subsample=1
# [CV 5/5; 2/20] END colsample_bytree=1, learning_rate=0.15, max_depth=10, n_estimators=500, subsample=1;, score=0.914 total time=   0.3s
# [CV 1/5; 3/20] START colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1
# [CV 1/5; 3/20] END colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1;, score=0.919 total time=   0.0s
# [CV 2/5; 3/20] START colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1
# [CV 2/5; 3/20] END colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1;, score=0.920 total time=   0.0s
# [CV 3/5; 3/20] START colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1
# [CV 3/5; 3/20] END colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1;, score=0.912 total time=   0.1s
# [CV 4/5; 3/20] START colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1
# [CV 4/5; 3/20] END colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1;, score=0.909 total time=   0.1s
# [CV 5/5; 3/20] START colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1
# [CV 5/5; 3/20] END colsample_bytree=0.1, learning_rate=0.2, max_depth=5, n_estimators=200, subsample=1;, score=0.918 total time=   0.0s
# [CV 1/5; 4/20] START colsample_bytree=1, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1
# [CV 1/5; 4/20] END colsample_bytree=1, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1;, score=0.915 total time=   0.1s
# [CV 2/5; 4/20] START colsample_bytree=1, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1
# [CV 2/5; 4/20] END colsample_bytree=1, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1;, score=0.918 total time=   0.1s
# [CV 3/5; 4/20] START colsample_bytree=1, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1
# [CV 3/5; 4/20] END colsample_bytree=1, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1;, score=0.915 total time=   0.1s
# [CV 4/5; 4/20] START colsample_bytree=1, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1
# [CV 4/5; 4/20] END colsample_bytree=1, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1;, score=0.912 total time=   0.1s
# [CV 5/5; 4/20] START colsample_bytree=1, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1
# [CV 5/5; 4/20] END colsample_bytree=1, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=1;, score=0.920 total time=   0.1s
# [CV 1/5; 5/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=500, subsample=0.1
# [CV 1/5; 5/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=500, subsample=0.1;, score=0.916 total time=   0.2s
# [CV 2/5; 5/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=500, subsample=0.1
# [CV 2/5; 5/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=500, subsample=0.1;, score=0.921 total time=   0.2s
# [CV 3/5; 5/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=500, subsample=0.1
# [CV 3/5; 5/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=500, subsample=0.1;, score=0.914 total time=   0.2s
# [CV 4/5; 5/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=500, subsample=0.1
# [CV 4/5; 5/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=500, subsample=0.1;, score=0.912 total time=   0.2s
# [CV 5/5; 5/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=500, subsample=0.1
# [CV 5/5; 5/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=500, subsample=0.1;, score=0.919 total time=   0.2s
# [CV 1/5; 6/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=3, n_estimators=100, subsample=1
# [CV 1/5; 6/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=3, n_estimators=100, subsample=1;, score=0.916 total time=   0.0s
# [CV 2/5; 6/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=3, n_estimators=100, subsample=1
# [CV 2/5; 6/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=3, n_estimators=100, subsample=1;, score=0.922 total time=   0.0s
# [CV 3/5; 6/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=3, n_estimators=100, subsample=1
# [CV 3/5; 6/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=3, n_estimators=100, subsample=1;, score=0.915 total time=   0.0s
# [CV 4/5; 6/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=3, n_estimators=100, subsample=1
# [CV 4/5; 6/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=3, n_estimators=100, subsample=1;, score=0.912 total time=   0.0s
# [CV 5/5; 6/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=3, n_estimators=100, subsample=1
# [CV 5/5; 6/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=3, n_estimators=100, subsample=1;, score=0.919 total time=   0.0s
# [CV 1/5; 7/20] START colsample_bytree=1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5
# [CV 1/5; 7/20] END colsample_bytree=1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5;, score=0.916 total time=   0.0s
# [CV 2/5; 7/20] START colsample_bytree=1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5
# [CV 2/5; 7/20] END colsample_bytree=1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5;, score=0.921 total time=   0.0s
# [CV 3/5; 7/20] START colsample_bytree=1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5
# [CV 3/5; 7/20] END colsample_bytree=1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5;, score=0.915 total time=   0.0s
# [CV 4/5; 7/20] START colsample_bytree=1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5
# [CV 4/5; 7/20] END colsample_bytree=1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5;, score=0.912 total time=   0.0s
# [CV 5/5; 7/20] START colsample_bytree=1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5
# [CV 5/5; 7/20] END colsample_bytree=1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.5;, score=0.921 total time=   0.0s
# [CV 1/5; 8/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5
# [CV 1/5; 8/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5;, score=0.919 total time=   0.0s
# [CV 2/5; 8/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5
# [CV 2/5; 8/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5;, score=0.923 total time=   0.0s
# [CV 3/5; 8/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5
# [CV 3/5; 8/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5;, score=0.916 total time=   0.0s
# [CV 4/5; 8/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5
# [CV 4/5; 8/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5;, score=0.911 total time=   0.0s
# [CV 5/5; 8/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5
# [CV 5/5; 8/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.5;, score=0.919 total time=   0.0s
# [CV 1/5; 9/20] START colsample_bytree=0.3, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1
# [CV 1/5; 9/20] END colsample_bytree=0.3, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1;, score=0.919 total time=   0.0s
# [CV 2/5; 9/20] START colsample_bytree=0.3, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1
# [CV 2/5; 9/20] END colsample_bytree=0.3, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1;, score=0.921 total time=   0.0s
# [CV 3/5; 9/20] START colsample_bytree=0.3, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1
# [CV 3/5; 9/20] END colsample_bytree=0.3, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1;, score=0.911 total time=   0.0s
# [CV 4/5; 9/20] START colsample_bytree=0.3, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1
# [CV 4/5; 9/20] END colsample_bytree=0.3, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1;, score=0.912 total time=   0.0s
# [CV 5/5; 9/20] START colsample_bytree=0.3, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1
# [CV 5/5; 9/20] END colsample_bytree=0.3, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1;, score=0.917 total time=   0.0s
# [CV 1/5; 10/20] START colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.1
# [CV 1/5; 10/20] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.1;, score=0.918 total time=   0.1s
# [CV 2/5; 10/20] START colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.1
# [CV 2/5; 10/20] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.1;, score=0.921 total time=   0.1s
# [CV 3/5; 10/20] START colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.1
# [CV 3/5; 10/20] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.1;, score=0.913 total time=   0.1s
# [CV 4/5; 10/20] START colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.1
# [CV 4/5; 10/20] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.1;, score=0.912 total time=   0.1s
# [CV 5/5; 10/20] START colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.1
# [CV 5/5; 10/20] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500, subsample=0.1;, score=0.918 total time=   0.1s
# [CV 1/5; 11/20] START colsample_bytree=0.1, learning_rate=0.03, max_depth=3, n_estimators=1000, subsample=0.1
# [CV 1/5; 11/20] END colsample_bytree=0.1, learning_rate=0.03, max_depth=3, n_estimators=1000, subsample=0.1;, score=0.916 total time=   0.4s
# [CV 2/5; 11/20] START colsample_bytree=0.1, learning_rate=0.03, max_depth=3, n_estimators=1000, subsample=0.1
# [CV 2/5; 11/20] END colsample_bytree=0.1, learning_rate=0.03, max_depth=3, n_estimators=1000, subsample=0.1;, score=0.918 total time=   0.4s
# [CV 3/5; 11/20] START colsample_bytree=0.1, learning_rate=0.03, max_depth=3, n_estimators=1000, subsample=0.1
# [CV 3/5; 11/20] END colsample_bytree=0.1, learning_rate=0.03, max_depth=3, n_estimators=1000, subsample=0.1;, score=0.913 total time=   0.4s
# [CV 4/5; 11/20] START colsample_bytree=0.1, learning_rate=0.03, max_depth=3, n_estimators=1000, subsample=0.1
# [CV 4/5; 11/20] END colsample_bytree=0.1, learning_rate=0.03, max_depth=3, n_estimators=1000, subsample=0.1;, score=0.913 total time=   0.4s
# [CV 5/5; 11/20] START colsample_bytree=0.1, learning_rate=0.03, max_depth=3, n_estimators=1000, subsample=0.1
# [CV 5/5; 11/20] END colsample_bytree=0.1, learning_rate=0.03, max_depth=3, n_estimators=1000, subsample=0.1;, score=0.918 total time=   0.4s
# [CV 1/5; 12/20] START colsample_bytree=0.1, learning_rate=0.05, max_depth=10, n_estimators=2000, subsample=0.1
# [CV 1/5; 12/20] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10, n_estimators=2000, subsample=0.1;, score=0.918 total time=   1.8s
# [CV 2/5; 12/20] START colsample_bytree=0.1, learning_rate=0.05, max_depth=10, n_estimators=2000, subsample=0.1
# [CV 2/5; 12/20] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10, n_estimators=2000, subsample=0.1;, score=0.915 total time=   1.8s
# [CV 3/5; 12/20] START colsample_bytree=0.1, learning_rate=0.05, max_depth=10, n_estimators=2000, subsample=0.1
# [CV 3/5; 12/20] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10, n_estimators=2000, subsample=0.1;, score=0.907 total time=   1.4s
# [CV 4/5; 12/20] START colsample_bytree=0.1, learning_rate=0.05, max_depth=10, n_estimators=2000, subsample=0.1
# [CV 4/5; 12/20] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10, n_estimators=2000, subsample=0.1;, score=0.906 total time=   1.5s
# [CV 5/5; 12/20] START colsample_bytree=0.1, learning_rate=0.05, max_depth=10, n_estimators=2000, subsample=0.1
# [CV 5/5; 12/20] END colsample_bytree=0.1, learning_rate=0.05, max_depth=10, n_estimators=2000, subsample=0.1;, score=0.913 total time=   1.4s
# [CV 1/5; 13/20] START colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.3
# [CV 1/5; 13/20] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.3;, score=0.916 total time=   0.0s
# [CV 2/5; 13/20] START colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.3
# [CV 2/5; 13/20] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.3;, score=0.920 total time=   0.0s
# [CV 3/5; 13/20] START colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.3
# [CV 3/5; 13/20] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.3;, score=0.914 total time=   0.0s
# [CV 4/5; 13/20] START colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.3
# [CV 4/5; 13/20] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.3;, score=0.912 total time=   0.0s
# [CV 5/5; 13/20] START colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.3
# [CV 5/5; 13/20] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.3;, score=0.920 total time=   0.0s
# [CV 1/5; 14/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1
# [CV 1/5; 14/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1;, score=0.916 total time=   0.0s
# [CV 2/5; 14/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1
# [CV 2/5; 14/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1;, score=0.918 total time=   0.0s
# [CV 3/5; 14/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1
# [CV 3/5; 14/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1;, score=0.911 total time=   0.0s
# [CV 4/5; 14/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1
# [CV 4/5; 14/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1;, score=0.913 total time=   0.0s
# [CV 5/5; 14/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1
# [CV 5/5; 14/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=200, subsample=1;, score=0.918 total time=   0.0s
# [CV 1/5; 15/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=1000, subsample=0.1
# [CV 1/5; 15/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=1000, subsample=0.1;, score=0.914 total time=   0.7s
# [CV 2/5; 15/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=1000, subsample=0.1
# [CV 2/5; 15/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=1000, subsample=0.1;, score=0.914 total time=   0.7s
# [CV 3/5; 15/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=1000, subsample=0.1
# [CV 3/5; 15/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=1000, subsample=0.1;, score=0.904 total time=   0.7s
# [CV 4/5; 15/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=1000, subsample=0.1
# [CV 4/5; 15/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=1000, subsample=0.1;, score=0.904 total time=   0.8s
# [CV 5/5; 15/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=1000, subsample=0.1
# [CV 5/5; 15/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=1000, subsample=0.1;, score=0.908 total time=   0.8s
# [CV 1/5; 16/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1
# [CV 1/5; 16/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1;, score=0.915 total time=   0.4s
# [CV 2/5; 16/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1
# [CV 2/5; 16/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1;, score=0.916 total time=   0.4s
# [CV 3/5; 16/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1
# [CV 3/5; 16/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1;, score=0.907 total time=   0.4s
# [CV 4/5; 16/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1
# [CV 4/5; 16/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1;, score=0.909 total time=   0.4s
# [CV 5/5; 16/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1
# [CV 5/5; 16/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=10, n_estimators=500, subsample=0.1;, score=0.916 total time=   0.4s
# [CV 1/5; 17/20] START colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=1
# [CV 1/5; 17/20] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=1;, score=0.918 total time=   0.4s
# [CV 2/5; 17/20] START colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=1
# [CV 2/5; 17/20] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=1;, score=0.919 total time=   0.4s
# [CV 3/5; 17/20] START colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=1
# [CV 3/5; 17/20] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=1;, score=0.911 total time=   0.4s
# [CV 4/5; 17/20] START colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=1
# [CV 4/5; 17/20] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=1;, score=0.909 total time=   0.4s
# [CV 5/5; 17/20] START colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=1
# [CV 5/5; 17/20] END colsample_bytree=0.5, learning_rate=0.05, max_depth=10, n_estimators=500, subsample=1;, score=0.918 total time=   0.4s
# [CV 1/5; 18/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 1/5; 18/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.918 total time=   1.6s
# [CV 2/5; 18/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 2/5; 18/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.919 total time=   1.5s
# [CV 3/5; 18/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 3/5; 18/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.914 total time=   1.7s
# [CV 4/5; 18/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 4/5; 18/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.911 total time=   1.6s
# [CV 5/5; 18/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 5/5; 18/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.917 total time=   1.7s
# [CV 1/5; 19/20] START colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.1
# [CV 1/5; 19/20] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.1;, score=0.919 total time=   0.8s
# [CV 2/5; 19/20] START colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.1
# [CV 2/5; 19/20] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.1;, score=0.915 total time=   0.7s
# [CV 3/5; 19/20] START colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.1
# [CV 3/5; 19/20] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.1;, score=0.906 total time=   0.7s
# [CV 4/5; 19/20] START colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.1
# [CV 4/5; 19/20] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.1;, score=0.903 total time=   0.8s
# [CV 5/5; 19/20] START colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.1
# [CV 5/5; 19/20] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=1000, subsample=0.1;, score=0.910 total time=   0.7s
# [CV 1/5; 20/20] START colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 1/5; 20/20] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.917 total time=   1.5s
# [CV 2/5; 20/20] START colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 2/5; 20/20] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.914 total time=   1.4s
# [CV 3/5; 20/20] START colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 3/5; 20/20] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.905 total time=   1.4s
# [CV 4/5; 20/20] START colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 4/5; 20/20] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.905 total time=   1.4s
# [CV 5/5; 20/20] START colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 5/5; 20/20] END colsample_bytree=0.1, learning_rate=0.1, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.909 total time=   1.5s
# {'subsample': 0.5, 'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.1, 'colsample_bytree': 0.5}

# %%
model = LGBMClassifier(n_estimators=200, max_depth=10, learning_rate=0.03, \
                    colsample_bytree=0.5, subsample=1)
model.fit(data_cleaned_train_x, data_cleaned_train_y)
data_cleaned_test_y_predict = model.predict(data_cleaned_test_x)
print(accuracy_score(data_cleaned_test_y, data_cleaned_test_y_predict), roc_auc_score(data_cleaned_test_y, data_cleaned_test_y_predict))
# Out:
# 0.9166375698324022 0.7345991618514455

# %% [markdown]
# <a id="step5"></a>
# # 5. Step 5 - Conclusion
