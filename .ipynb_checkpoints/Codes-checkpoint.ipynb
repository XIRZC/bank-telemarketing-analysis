# %% [markdown]
# # <center> Predicting whether Marketing Campaigns will Success

# %% [markdown]
# # Table of Contents
#
# 1. **[Step 1 - Environment Preparation](#step1)**
# 2. **[Step 2 - Data Wrangling](#step2)**
# 3. **[Step 3 - Exploratory Data Analysis](#step3)**
# 4. **[Step 4 - Data Modeling with Machine Learning](#step4)**
# 5. **[Step 5 - Conclusion](#step5)**

# %% [markdown]
# <a id="step1"><a/>
# # 1. Step 1 - Environment Preparation
# Environment Preparation refers to loading essential packages, loading and skimming the dataset.

# %% [markdown]
# ## 1.1 Import Necessary Packages

# %%
# Load Essential Libraries
import sys
print("Python version: {}". format(sys.version))

import pandas as pd #collection of functions for data processing and analysis modeled after R dataframes with SQL like features
print("Pandas version: {}". format(pd.__version__))

import matplotlib #collection of functions for scientific and publication-ready visualization
print("Matplotlib version: {}". format(matplotlib.__version__))

import numpy as np #foundational package for scientific computing
print("NumPy version: {}". format(np.__version__))

import scipy as sp #collection of functions for scientific computing and advance mathematics
print("SciPy version: {}". format(sp.__version__)) 

import sklearn #collection of machine learning algorithms
print("Scikit-learn version: {}". format(sklearn.__version__))

import IPython
from IPython import display #pretty printing of dataframes in Jupyter notebook
print("IPython version: {}". format(IPython.__version__)) 

#misc libraries
import random
import time

#ignore warnings
import warnings
warnings.filterwarnings('ignore')
print('-'*25)

# Input data files are available in the "./Bank_Data_20C/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in Bank_Data_20C directory

from subprocess import check_output
print(check_output(["ls", "./Bank_Data_20C"]).decode("utf8"))

# Any results you write to the current directory are saved as output.

#Common Model Algorithms
from sklearn import svm, tree, linear_model, neighbors, naive_bayes, ensemble, discriminant_analysis, gaussian_process
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

#Common Model Helpers
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MinMaxScaler, StandardScaler, RobustScaler
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold, KFold, GridSearchCV
from sklearn.metrics import f1_score, roc_auc_score,accuracy_score,confusion_matrix, precision_recall_curve, auc, roc_curve, recall_score, classification_report

#Visualization
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pandas.plotting import scatter_matrix

#Configure Visualization Defaults
#%matplotlib inline = show plots in Jupyter Notebook browser
# %matplotlib inline
mpl.style.use('ggplot')
sns.set_style('white')
pylab.rcParams['figure.figsize'] = 12,8
# Out:
# Python version: 3.7.15 (default, Nov 24 2022, 21:12:53)
# [GCC 11.2.0]
# Pandas version: 1.3.5
# Matplotlib version: 3.5.3
# NumPy version: 1.21.5
# SciPy version: 1.7.3
# Scikit-learn version: 1.0.2
# IPython version: 7.34.0
# -------------------------
# bank-additional-names.txt
# bank.csv
# bank-full.csv

# %% [markdown]
# ## 1.2 Load DataSet from CSV

# %%
BANK_DATA_20C_DIR = "./Bank_Data_20C"
BANK_DATA_16C_DIR = "./Bank_Data_16C"
FILE_FULL = "bank-full.csv"
FILE_TEN_PERCENT = "bank.csv"

def print_verbose(info):
    print('-'*100)
    print(info)
    print()

data_20c = pd.read_csv(f"{BANK_DATA_20C_DIR}/{FILE_FULL}", sep=';')
data_16c = pd.read_csv(f"{BANK_DATA_16C_DIR}/{FILE_FULL}", sep=';')

# Use Full Bank Data with 20 features by default
data = data_20c

# %% [markdown]
# ## 1.3 Quick Look the Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# std        1.570960        0.578840       4.628198      1.734447     72.251528
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
data.describe(include=['O'])
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41188    41188              41188   41188   41188  41188     41188
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome      y
# count   41188       41188        41188  41188
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13769        8623        35563  36548

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 12

# %%
data.sample(10)
# Out:
#        age          job   marital            education  default housing loan  \
# 23153   29       admin.   married    university.degree       no      no   no
# 15859   54      retired   married             basic.4y  unknown     yes  yes
# 21679   32       admin.    single    university.degree       no     yes  yes
# 10644   47   technician   married  professional.course       no      no   no
# 27685   51  blue-collar   married             basic.4y       no     yes  yes
# 15443   47  blue-collar   married             basic.9y  unknown     yes   no
# 5491    42       admin.   married    university.degree       no      no   no
# 35615   29   technician    single    university.degree       no      no   no
# 14564   48  blue-collar   married             basic.4y  unknown     yes   no
# 17649   56  blue-collar  divorced             basic.9y       no     yes  yes
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 23153   cellular   aug         tue  ...         2    999         0
# 15859   cellular   jul         mon  ...         1    999         0
# 21679   cellular   aug         tue  ...         2    999         0
# 10644  telephone   jun         tue  ...         2    999         0
# 27685  telephone   dec         mon  ...         1    999         0
# 15443   cellular   jul         fri  ...         1    999         0
# 5491   telephone   may         mon  ...         1    999         0
# 35615   cellular   may         mon  ...         3    999         0
# 14564  telephone   jul         tue  ...         1    999         0
# 17649   cellular   jul         mon  ...         3    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 23153  nonexistent          1.4          93.444          -36.1      4.965
# 15859  nonexistent          1.4          93.918          -42.7      4.960
# 21679  nonexistent          1.4          93.444          -36.1      4.963
# 10644  nonexistent          1.4          94.465          -41.8      4.961
# 27685  nonexistent         -0.2          92.756          -45.9      3.488
# 15443  nonexistent          1.4          93.918          -42.7      4.957
# 5491   nonexistent          1.1          93.994          -36.4      4.857
# 35615  nonexistent         -1.8          92.893          -46.2      1.244
# 14564  nonexistent          1.4          93.918          -42.7      4.961
# 17649  nonexistent          1.4          93.918          -42.7      4.962
#
#        nr.employed   y
# 23153       5228.1  no
# 15859       5228.1  no
# 21679       5228.1  no
# 10644       5228.1  no
# 27685       5176.3  no
# 15443       5228.1  no
# 5491        5191.0  no
# 35615       5099.1  no
# 14564       5228.1  no
# 17649       5228.1  no
#
# [10 rows x 21 columns]

# %% [markdown]
# <a id="step3"></a>
# # 2. Step 2 - Exploratory Data Analysis

# %% [markdown]
# ## 2.1 Uni-Variable Distribution

# %% [markdown]
# ### 2.1.1 Categorical Features

# %%
def cat_visualize_bar(data, column):
    plt.figure(figsize=(8,4))
    ax=sns.countplot(x=column, data=data)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/len(data))
        x = p.get_x() + p.get_width()
        y = p.get_height()
        ax.annotate(percentage, (x, y),ha='center')
def cat_visualize_pie(data, column):
    percentages = (data[column].value_counts()/data.shape[0]*100)
    percentages_data, percentages_labels = list(percentages), list(percentages.index)
    plt.pie(percentages_data, labels=percentages_labels, autopct='%.1f%%')
    plt.title(f"`{column}` Percentage")
def cat_visualize_count_by_target(data, column):
    Y = data[column]
    total = len(Y)*1.
    ax=sns.countplot(x=column, data=data, hue='y')
    for p in ax.patches:
      ax.annotate('{:.1f}%'.format(100*p.get_height()/total), (p.get_x()+0.1, p.get_height()+5))
    ax.yaxis.set_ticks(np.linspace(0, total, 11))
    ax.set_yticklabels(map('{:.1f}%'.format, 100*ax.yaxis.get_majorticklocs()/total))
    ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %% [markdown]
# #### job

# %%
cat_visualize_pie(data, 'job')

# %%
cat_visualize_count_by_target(data, 'job')

# %% [markdown]
# #### marital

# %%
cat_visualize_pie(data, 'marital')

# %%
cat_visualize_count_by_target(data, 'marital')

# %% [markdown]
# #### education

# %%
cat_visualize_pie(data, 'education')

# %%
cat_visualize_count_by_target(data, 'education')

# %% [markdown]
# #### default

# %%
cat_visualize_pie(data, 'default')

# %%
cat_visualize_count_by_target(data, 'default')

# %% [markdown]
# #### housing

# %%
cat_visualize_pie(data, 'housing')

# %%
cat_visualize_count_by_target(data, 'housing')

# %% [markdown]
# #### loan

# %%
cat_visualize_pie(data, 'loan')

# %%
cat_visualize_count_by_target(data, 'loan')

# %% [markdown]
# #### contact

# %%
cat_visualize_pie(data, 'contact')

# %%
cat_visualize_count_by_target(data, 'contact')

# %% [markdown]
# #### month

# %%
cat_visualize_pie(data, 'month')

# %%
cat_visualize_count_by_target(data, 'month')

# %% [markdown]
# #### day_of_week

# %%
cat_visualize_pie(data, 'day_of_week')

# %%
cat_visualize_count_by_target(data, 'day_of_week')

# %% [markdown]
# #### poutcome

# %%
cat_visualize_pie(data, 'poutcome')

# %%
cat_visualize_count_by_target(data, 'poutcome')

# %% [markdown]
# #### target

# %%
cat_visualize_pie(data, 'y')

# %% [markdown]
# ### 2.1.2 Numerical Features

# %% [markdown]
# #### age

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='age', y='y', data=data)
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.histplot, 'age', bins=20)

# %% [markdown]
# #### duration

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='duration', y='y', data=data)
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'duration')

# %% [markdown]
# #### campaign

# %%
# plt.figure(figsize=(8,4))
# sns.boxplot(x='campaign', y='y', data=data)
cat_visualize_pie(data, 'campaign')
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'campaign')

# %% [markdown]
# #### pdays

# %%
cat_visualize_pie(data, 'pdays')
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'pdays')

# %% [markdown]
# #### previous

# %%
cat_visualize_pie(data, 'previous')
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'previous')

# %% [markdown]
# #### emp.var.rate

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='emp.var.rate', y='y', data=data)
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'emp.var.rate')

# %% [markdown]
# #### cons.price.idx

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='cons.price.idx', y='y', data=data)
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'cons.price.idx')

# %% [markdown]
# #### cons.conf.idx

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='cons.conf.idx', y='y', data=data)
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'cons.conf.idx')

# %% [markdown]
# #### euribor3m

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='euribor3m', y='y', data=data)
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'euribor3m')

# %% [markdown]
# #### nr.employed

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='nr.employed', y='y', data=data)
fg=sns.FacetGrid(data=data, col='y', height=4, aspect=1.2)
fg.map(sns.distplot, 'nr.employed')

# %% [markdown]
# ## 2.2 Multi-Vairable Correlation

# %% [markdown]
# ## 2.3 Correlation Heatmap of Dataset

# %%
def correlation_heatmap(data):
    _ , ax = plt.subplots(figsize =(14, 12))
    colormap = sns.diverging_palette(220, 10, as_cmap = True)
    
    _ = sns.heatmap(
        data.corr(), 
        cmap = colormap,
        square=True, 
        cbar_kws={'shrink':.9 }, 
        ax=ax,
        annot=True, 
        linewidths=0.1,vmax=1.0, linecolor='white',
        annot_kws={'fontsize':12 }
    )
    
    plt.title('Pearson Correlation of Features', y=1.05, size=15)

correlation_heatmap(data)

# %% [markdown]
# <a id="step2"></a>
# # 3. Step 3 - Data Wrangling
# Data Wrangling refers to the 4C process: Data Correcting, Completing, Creating and Converting.
# 1) Correcting aberrant values and outliers.
# 2) Completing missing information.
# 3) Creating new features for analysis.
# 4) Converting fields to the correct format for calculations and presentation.

# %%
# All Four Stages CONSTANT Parameters or Options
# Stage 1: Data Correcting: Directly drop dirty data
DROP_USELESS, USELESS_COLUMNS = True, ['month', 'day_of_week'] # possibly useless columns ['marital', 'month', 'day_of_week']
DROP_NOISY, NOISY_COLUMNS = True, ['default', 'pdays'] # possibly noisy columns ['default', 'pdays']: default with higher than 20% missing values, while pdays with too many outliers
DROP_UNPRACTICAL, UNPRACTICAL_COLUMNS = False, ['duration'] # remain if benchmark purpose, drop if practical use
# Stage 2: Data Completing: directly drop low-frequency rows with 'unknown' values in some columns rather than add some noise

# Stage 3: Data Creating
CREATE_COLUMNS = ['age']
# Stage 4: Data Converting: categorical featuers encoding and numercial features scaling
ENCODE_OPTION = 'label' # onehot or label encoding for categorical features
IF_SCALE = True # whether to scale or not
SCALE_OPTION = 'minmax' # minmax, robust or standard scaling for all numerical featuers

# %% [markdown]
# ## 3.1 Data Correcting
# In this stage, I will
# 1. drop ('marital', 'day_of_week', 'month') because these are useless features for prediting the target
# 2. drop ('default') because there are too many 'unknown' values (higher than 20%) in this column
# 3. drop ('duration') because in real-time practice there is no duration feature

# %%
data_corrected = data
drop_columns = []
if DROP_USELESS:
    drop_columns.extend(USELESS_COLUMNS)
if DROP_NOISY:
    drop_columns.extend(NOISY_COLUMNS)
if DROP_UNPRACTICAL:
    drop_unpractical.extend(UNPRACTICAL_COLUMNS)
data_corrected = data_corrected.drop(drop_columns, axis=1)
data_corrected = data_corrected.drop_duplicates()

# %%
data_corrected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41172 entries, 0 to 41187
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41172 non-null  int64
#  1   job             41172 non-null  object
#  2   marital         41172 non-null  object
#  3   education       41172 non-null  object
#  4   housing         41172 non-null  object
#  5   loan            41172 non-null  object
#  6   contact         41172 non-null  object
#  7   duration        41172 non-null  int64
#  8   campaign        41172 non-null  int64
#  9   previous        41172 non-null  int64
#  10  poutcome        41172 non-null  object
#  11  emp.var.rate    41172 non-null  float64
#  12  cons.price.idx  41172 non-null  float64
#  13  cons.conf.idx   41172 non-null  float64
#  14  euribor3m       41172 non-null  float64
#  15  nr.employed     41172 non-null  float64
#  16  y               41172 non-null  object
# dtypes: float64(5), int64(4), object(8)
# memory usage: 5.7+ MB

# %%
data_corrected.describe(include=['number'])
# Out:
#                 age      duration      campaign      previous  emp.var.rate  \
# count  41172.000000  41172.000000  41172.000000  41172.000000  41172.000000
# mean      40.023365    258.331317      2.568032      0.173030      0.081808
# std       10.420784    259.312967      2.770410      0.494985      1.570916
# min       17.000000      0.000000      1.000000      0.000000     -3.400000
# 25%       32.000000    102.000000      1.000000      0.000000     -1.800000
# 50%       38.000000    180.000000      2.000000      0.000000      1.100000
# 75%       47.000000    319.000000      3.000000      0.000000      1.400000
# max       98.000000   4918.000000     56.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    41172.000000   41172.000000  41172.000000  41172.000000
# mean        93.575706     -40.503276      3.621168   5167.030739
# std          0.578859       4.627895      1.734475     72.253427
# min         92.201000     -50.800000      0.634000   4963.600000
# 25%         93.075000     -42.700000      1.344000   5099.100000
# 50%         93.749000     -41.800000      4.857000   5191.000000
# 75%         93.994000     -36.400000      4.961000   5228.100000
# max         94.767000     -26.900000      5.045000   5228.100000

# %%
data_corrected.describe(include=['object', 'category'])
# Out:
#            job  marital          education housing   loan   contact  \
# count    41172    41172              41172   41172  41172     41172
# unique      12        4                  8       3      3         2
# top     admin.  married  university.degree     yes     no  cellular
# freq     10418    24917              12163   21569  33934     26133
#
#            poutcome      y
# count         41172  41172
# unique            3      2
# top     nonexistent     no
# freq          35547  36533

# %%
data_corrected.sample(10)
# Out:
#        age          job   marital            education housing loan  \
# 6258    53   technician   married              unknown     yes   no
# 24014   44       admin.  divorced          high.school     yes   no
# 1673    33   technician  divorced  professional.course     yes   no
# 40379   18      student    single              unknown     yes   no
# 22127   42   technician  divorced          high.school     yes   no
# 5429    32  blue-collar   married             basic.9y      no   no
# 7773    39   unemployed   married    university.degree     yes   no
# 29042   32  blue-collar   married             basic.9y      no   no
# 30675   37       admin.   married             basic.9y     yes   no
# 22916   46  blue-collar   married             basic.4y      no   no
#
#          contact  duration  campaign  previous     poutcome  emp.var.rate  \
# 6258   telephone       241         2         0  nonexistent           1.1
# 24014  telephone       294         1         0  nonexistent          -0.1
# 1673   telephone        44         1         0  nonexistent           1.1
# 40379   cellular       561         1         2      failure          -1.7
# 22127   cellular       140         7         0  nonexistent           1.4
# 5429   telephone       559         3         0  nonexistent           1.1
# 7773   telephone       108         4         0  nonexistent           1.4
# 29042   cellular       334         2         0  nonexistent          -1.8
# 30675   cellular        24         7         0  nonexistent          -1.8
# 22916   cellular       251         3         0  nonexistent           1.4
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 6258           93.994          -36.4      4.857       5191.0   no
# 24014          93.798          -40.4      4.968       5195.8  yes
# 1673           93.994          -36.4      4.855       5191.0   no
# 40379          94.027          -38.3      0.900       4991.6  yes
# 22127          93.444          -36.1      4.963       5228.1   no
# 5429           93.994          -36.4      4.857       5191.0   no
# 7773           94.465          -41.8      4.865       5228.1   no
# 29042          93.075          -47.1      1.405       5099.1   no
# 30675          92.893          -46.2      1.344       5099.1   no
# 22916          93.444          -36.1      4.965       5228.1   no

# %%
data_corrected.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# housing           0
# loan              0
# contact           0
# duration          0
# campaign          0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data_corrected.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 3.2 Data Completing
# There are no explicit missing values for numerical features, but there are implicit missing values for categorical features after dropping ('poutcome', 'default'):
# - job: 'unknown' 0.8%
# - marital: 'unknown': 0.2%
# - education: 'unknown' 4.2%
# - housing: 'unknown' 2.4%
# - loan: 'unknown' 2.4%

# %% [markdown]
# As we cannot simply fill these 'unknown' values with most frequent values, we can simply drop these rows because these valus account not so much.

# %%
data_completed = data_corrected.copy()
cat_columns = list(data_completed.select_dtypes(include=['object']).columns)
for column in cat_columns:
    data_completed = data_completed.drop(data_completed[data_completed[column]=='unknown'].index)

# %%
data_completed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38230 entries, 0 to 41187
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             38230 non-null  int64
#  1   job             38230 non-null  object
#  2   marital         38230 non-null  object
#  3   education       38230 non-null  object
#  4   housing         38230 non-null  object
#  5   loan            38230 non-null  object
#  6   contact         38230 non-null  object
#  7   duration        38230 non-null  int64
#  8   campaign        38230 non-null  int64
#  9   previous        38230 non-null  int64
#  10  poutcome        38230 non-null  object
#  11  emp.var.rate    38230 non-null  float64
#  12  cons.price.idx  38230 non-null  float64
#  13  cons.conf.idx   38230 non-null  float64
#  14  euribor3m       38230 non-null  float64
#  15  nr.employed     38230 non-null  float64
#  16  y               38230 non-null  object
# dtypes: float64(5), int64(4), object(8)
# memory usage: 6.3+ MB

# %%
data_completed.describe(include=['number'])
# Out:
#                 age      duration      campaign      previous  emp.var.rate  \
# count  38230.000000  38230.000000  38230.000000  38230.000000  38230.000000
# mean      39.859953    258.252969      2.567094      0.170076      0.082812
# std       10.288796    259.827170      2.767875      0.487253      1.565890
# min       17.000000      0.000000      1.000000      0.000000     -3.400000
# 25%       32.000000    102.000000      1.000000      0.000000     -1.800000
# 50%       38.000000    180.000000      2.000000      0.000000      1.100000
# 75%       47.000000    319.000000      3.000000      0.000000      1.400000
# max       98.000000   4918.000000     43.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    38230.000000   38230.000000  38230.000000  38230.000000
# mean        93.570365     -40.541964      3.623202   5167.428750
# std          0.576382       4.622818      1.730244     71.761949
# min         92.201000     -50.800000      0.634000   4963.600000
# 25%         93.075000     -42.700000      1.344000   5099.100000
# 50%         93.444000     -41.800000      4.857000   5191.000000
# 75%         93.994000     -36.400000      4.961000   5228.100000
# max         94.767000     -26.900000      5.045000   5228.100000

# %%
data_completed.describe(include=['object', 'category'])
# Out:
#            job  marital          education housing   loan   contact  \
# count    38230    38230              38230   38230  38230     38230
# unique      11        3                  7       2      2         2
# top     admin.  married  university.degree     yes     no  cellular
# freq      9933    23173              11816   20571  32271     24430
#
#            poutcome      y
# count         38230  38230
# unique            3      2
# top     nonexistent     no
# freq          33051  33973

# %%
data_completed.sample(10)
# Out:
#        age           job   marital            education housing loan  \
# 6020    31        admin.  divorced          high.school      no   no
# 7078    36      services   married          high.school     yes   no
# 15730   48  entrepreneur   married             basic.9y      no   no
# 26024   32    management    single    university.degree      no   no
# 40533   28       student    single    university.degree     yes   no
# 8194    59       retired    single          high.school      no  yes
# 17670   42     housemaid   married             basic.4y     yes   no
# 40736   52        admin.   married  professional.course      no   no
# 20720   34        admin.   married    university.degree     yes   no
# 24399   32        admin.    single    university.degree      no   no
#
#          contact  duration  campaign  previous     poutcome  emp.var.rate  \
# 6020   telephone       271         3         0  nonexistent           1.1
# 7078   telephone       117         1         0  nonexistent           1.1
# 15730   cellular        90         1         0  nonexistent           1.4
# 26024   cellular       163         2         0  nonexistent          -0.1
# 40533  telephone         6         1         0  nonexistent          -1.7
# 8194   telephone       103         1         0  nonexistent           1.4
# 17670  telephone       122         3         0  nonexistent           1.4
# 40736   cellular       953         2         0  nonexistent          -1.1
# 20720   cellular       270         1         0  nonexistent           1.4
# 24399   cellular       137         1         1      failure          -0.1
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 6020           93.994          -36.4      4.857       5191.0   no
# 7078           93.994          -36.4      4.860       5191.0   no
# 15730          93.918          -42.7      4.960       5228.1   no
# 26024          93.200          -42.0      4.120       5195.8   no
# 40533          94.027          -38.3      0.890       4991.6   no
# 8194           94.465          -41.8      4.864       5228.1   no
# 17670          93.918          -42.7      4.962       5228.1   no
# 40736          94.199          -37.5      0.876       4963.6  yes
# 20720          93.444          -36.1      4.965       5228.1   no
# 24399          93.200          -42.0      4.191       5195.8   no

# %%
data_completed.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# housing           0
# loan              0
# contact           0
# duration          0
# campaign          0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data_completed.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 3.3 Data Creating
# 'age' feature need to be quantized into discrete bins to create new 'age_period' feature:

# %%
data_created = data_completed.copy()
for column in CREATE_COLUMNS:
    if column == 'age':
        data_created.insert(0, 'age_period', pd.cut(data_completed['age'].astype(int), 5))
        data_created = data_created.drop('age', axis=1)
data_created = data_created.drop_duplicates()

# %%
data_created.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38184 entries, 0 to 41187
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age_period      38184 non-null  category
#  1   job             38184 non-null  object
#  2   marital         38184 non-null  object
#  3   education       38184 non-null  object
#  4   housing         38184 non-null  object
#  5   loan            38184 non-null  object
#  6   contact         38184 non-null  object
#  7   duration        38184 non-null  int64
#  8   campaign        38184 non-null  int64
#  9   previous        38184 non-null  int64
#  10  poutcome        38184 non-null  object
#  11  emp.var.rate    38184 non-null  float64
#  12  cons.price.idx  38184 non-null  float64
#  13  cons.conf.idx   38184 non-null  float64
#  14  euribor3m       38184 non-null  float64
#  15  nr.employed     38184 non-null  float64
#  16  y               38184 non-null  object
# dtypes: category(1), float64(5), int64(3), object(8)
# memory usage: 5.0+ MB

# %%
data_created.describe(include=['number'])
# Out:
#            duration      campaign      previous  emp.var.rate  cons.price.idx  \
# count  38184.000000  38184.000000  38184.000000  38184.000000    38184.000000
# mean     258.394537      2.568510      0.170281      0.081851       93.570153
# std      259.936448      2.769151      0.487511      1.566167        0.576535
# min        0.000000      1.000000      0.000000     -3.400000       92.201000
# 25%      102.000000      1.000000      0.000000     -1.800000       93.075000
# 50%      180.000000      2.000000      0.000000      1.100000       93.444000
# 75%      320.000000      3.000000      0.000000      1.400000       93.994000
# max     4918.000000     43.000000      7.000000      1.400000       94.767000
#
#        cons.conf.idx     euribor3m   nr.employed
# count   38184.000000  38184.000000  38184.000000
# mean      -40.544657      3.622147   5167.394301
# std         4.623556      1.730559     71.778700
# min       -50.800000      0.634000   4963.600000
# 25%       -42.700000      1.344000   5099.100000
# 50%       -41.800000      4.857000   5191.000000
# 75%       -36.400000      4.961000   5228.100000
# max       -26.900000      5.045000   5228.100000

# %%
data_created.describe(include=['category', 'object'])
# Out:
#           age_period     job  marital          education housing   loan  \
# count          38184   38184    38184              38184   38184  38184
# unique             5      11        3                  7       2      2
# top     (33.2, 49.4]  admin.  married  university.degree     yes     no
# freq           18723    9914    23134              11799   20548  32227
#
#          contact     poutcome      y
# count      38184        38184  38184
# unique         2            3      2
# top     cellular  nonexistent     no
# freq       24406        33005  33927

# %%
data_created.sample(10)
# Out:
#            age_period            job   marital            education housing  \
# 25644    (33.2, 49.4]    blue-collar   married             basic.6y     yes
# 20165    (33.2, 49.4]     technician   married  professional.course     yes
# 19979    (49.4, 65.6]  self-employed   married    university.degree      no
# 10773    (33.2, 49.4]     management   married             basic.9y     yes
# 34903    (33.2, 49.4]    blue-collar  divorced             basic.9y      no
# 29721    (33.2, 49.4]    blue-collar   married          high.school     yes
# 38462    (33.2, 49.4]         admin.   married    university.degree      no
# 31376    (33.2, 49.4]    blue-collar  divorced             basic.9y      no
# 19235  (16.919, 33.2]         admin.    single    university.degree     yes
# 9877     (33.2, 49.4]    blue-collar   married             basic.4y      no
#
#       loan    contact  duration  campaign  previous     poutcome  \
# 25644   no   cellular       264         2         0  nonexistent
# 20165   no   cellular       105         1         0  nonexistent
# 19979   no   cellular      1242         3         0  nonexistent
# 10773   no  telephone       116         3         0  nonexistent
# 34903   no   cellular       409         1         1      failure
# 29721   no   cellular       143         1         1      failure
# 38462   no   cellular       281         1         2      failure
# 31376   no   cellular       482         2         0  nonexistent
# 19235   no   cellular        89         1         0  nonexistent
# 9877    no  telephone        95         2         0  nonexistent
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 25644          -0.1          93.200          -42.0      4.120       5195.8
# 20165           1.4          93.444          -36.1      4.965       5228.1
# 19979           1.4          93.444          -36.1      4.966       5228.1
# 10773           1.4          94.465          -41.8      4.961       5228.1
# 34903          -1.8          92.893          -46.2      1.250       5099.1
# 29721          -1.8          93.075          -47.1      1.405       5099.1
# 38462          -3.4          92.431          -26.9      0.730       5017.5
# 31376          -1.8          92.893          -46.2      1.334       5099.1
# 19235           1.4          93.444          -36.1      4.967       5228.1
# 9877            1.4          94.465          -41.8      4.959       5228.1
#
#          y
# 25644   no
# 20165   no
# 19979  yes
# 10773   no
# 34903  yes
# 29721   no
# 38462  yes
# 31376   no
# 19235   no
# 9877    no

# %%
data_created.isnull().sum()
# Out:
# age_period        0
# job               0
# marital           0
# education         0
# housing           0
# loan              0
# contact           0
# duration          0
# campaign          0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data_created.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 3.4 Data Converting
# There are several categorical object features(age_period, job, education, housing, loan and contact) need to be labeled:
# - age_period: (0-16.919, 16.919-33.2, 33.2-49.4, 49.4-65.6, 65.6-98.0)
# - job: ('admin', 'blue-collar', 'technician', 'services', 'management', 'retired', 'entrepreneur', 'self-employed', 'housemaid', 'unemployed', 'student')
# - marital: ('married', 'single', 'divorced')
# - education: ('university.degree', 'high.school', 'basic.9y', 'professional.course', 'basic.4y', 'basic.6y', 'illiterate')
# - housing ('yes', 'no')
# - loan ('yes', 'no')
# - contact ('cellular', 'telephone')
# - target ('yes', 'no')
# - month ('jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'dec', 'nov', 'dec')
# - day_of_week ('mon', 'tue', 'wed', 'thu', 'fri')

# %%
data_converted = data_created.copy()
cat_columns = list(data_converted.select_dtypes(include=['object']).columns)
cat_columns.remove('y')
encoder = LabelEncoder()

# age_period => age_period_code
data_converted['age_period_code'] = encoder.fit_transform(data_converted['age_period'])
data_converted = data_converted.drop(['age_period'], axis=1)

# y => target: yes => 1, no => 0
data_converted['target'] = encoder.fit_transform(data_converted['y'])
data_converted = data_converted.drop(['y'], axis=1)

# encode remaining categorical columns
if ENCODE_OPTION == 'onehot':
    data_converted = pd.get_dummies(data_converted)
else:
    for column in cat_columns:
        data_converted[f"{column}_code"] = encoder.fit_transform(data_converted[column])
        data_converted = data_converted.drop([column], axis=1)
    
# Scale and Normalize
if IF_SCALE:
    if SCALE_OPTION == 'minmax':
        scaler = MinMaxScaler()
    elif SCALE_OPTION == 'standard':
        scaler = StandardScaler()
    else:
        scaler = RobustScaler()
    num_columns = list(data_converted.select_dtypes(include=['number']).columns)
    for column in num_columns:
        data_converted[column] = pd.DataFrame(scaler.fit_transform(pd.DataFrame(data_converted[column])), index=data_converted.index, columns=[column])

# %%
data_converted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38184 entries, 0 to 41187
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   duration         38184 non-null  float64
#  1   campaign         38184 non-null  float64
#  2   previous         38184 non-null  float64
#  3   emp.var.rate     38184 non-null  float64
#  4   cons.price.idx   38184 non-null  float64
#  5   cons.conf.idx    38184 non-null  float64
#  6   euribor3m        38184 non-null  float64
#  7   nr.employed      38184 non-null  float64
#  8   age_period_code  38184 non-null  float64
#  9   target           38184 non-null  float64
#  10  job_code         38184 non-null  float64
#  11  marital_code     38184 non-null  float64
#  12  education_code   38184 non-null  float64
#  13  housing_code     38184 non-null  float64
#  14  loan_code        38184 non-null  float64
#  15  contact_code     38184 non-null  float64
#  16  poutcome_code    38184 non-null  float64
# dtypes: float64(17)
# memory usage: 5.2 MB

# %%
data_converted.describe(include=['number'])
# Out:
#            duration      campaign      previous  emp.var.rate  cons.price.idx  \
# count  38184.000000  38184.000000  38184.000000  38184.000000    38184.000000
# mean       0.052541      0.037345      0.024326      0.725386        0.533575
# std        0.052854      0.065932      0.069644      0.326285        0.224682
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%        0.020740      0.000000      0.000000      0.333333        0.340608
# 50%        0.036600      0.023810      0.000000      0.937500        0.484412
# 75%        0.065067      0.047619      0.000000      1.000000        0.698753
# max        1.000000      1.000000      1.000000      1.000000        1.000000
#
#        cons.conf.idx     euribor3m   nr.employed  age_period_code  \
# count   38184.000000  38184.000000  38184.000000     38184.000000
# mean        0.429094      0.677431      0.770489         0.221474
# std         0.193454      0.392328      0.271375         0.185472
# min         0.000000      0.000000      0.000000         0.000000
# 25%         0.338912      0.160961      0.512287         0.000000
# 50%         0.376569      0.957379      0.859735         0.250000
# 75%         0.602510      0.980957      1.000000         0.250000
# max         1.000000      1.000000      1.000000         1.000000
#
#              target      job_code  marital_code  education_code  housing_code  \
# count  38184.000000  38184.000000  38184.000000    38184.000000  38184.000000
# mean       0.111486      0.365417      0.584433        0.601967      0.538131
# std        0.314738      0.355536      0.302340        0.344259      0.498550
# min        0.000000      0.000000      0.000000        0.000000      0.000000
# 25%        0.000000      0.000000      0.500000        0.333333      0.000000
# 50%        0.000000      0.200000      0.500000        0.500000      1.000000
# 75%        0.000000      0.700000      1.000000        1.000000      1.000000
# max        1.000000      1.000000      1.000000        1.000000      1.000000
#
#           loan_code  contact_code  poutcome_code
# count  38184.000000  38184.000000   38184.000000
# mean       0.156008      0.360832       0.464737
# std        0.362867      0.480248       0.180736
# min        0.000000      0.000000       0.000000
# 25%        0.000000      0.000000       0.500000
# 50%        0.000000      0.000000       0.500000
# 75%        0.000000      1.000000       0.500000
# max        1.000000      1.000000       1.000000

# %%
data_converted.sample(10)
# Out:
#        duration  campaign  previous  emp.var.rate  cons.price.idx  \
# 15252  0.206995  0.000000       0.0        1.0000        0.669135
# 27202  0.012810  0.000000       0.0        0.6875        0.389322
# 3607   0.012810  0.000000       0.0        0.9375        0.698753
# 26233  0.057137  0.023810       0.0        0.6875        0.389322
# 16023  0.076454  0.000000       0.0        1.0000        0.669135
# 3445   0.099024  0.071429       0.0        0.9375        0.698753
# 15220  0.123221  0.047619       0.0        1.0000        0.669135
# 17960  0.047580  0.119048       0.0        1.0000        0.669135
# 17120  0.050020  0.023810       0.0        1.0000        0.669135
# 881    0.033347  0.023810       0.0        0.9375        0.698753
#
#        cons.conf.idx  euribor3m  nr.employed  age_period_code  target  \
# 15252       0.338912   0.980277     1.000000             0.00     0.0
# 27202       0.368201   0.767853     0.877883             0.50     0.0
# 3607        0.602510   0.957833     0.859735             0.25     0.0
# 26233       0.368201   0.780322     0.877883             0.25     0.0
# 16023       0.338912   0.980957     1.000000             0.00     0.0
# 3445        0.602510   0.958059     0.859735             0.25     0.0
# 15220       0.338912   0.980277     1.000000             0.00     0.0
# 17960       0.338912   0.980957     1.000000             0.00     0.0
# 17120       0.338912   0.981183     1.000000             0.25     0.0
# 881         0.602510   0.957153     0.859735             0.00     0.0
#
#        job_code  marital_code  education_code  housing_code  loan_code  \
# 15252       0.0           0.5        1.000000           0.0        0.0
# 27202       0.9           0.5        1.000000           1.0        1.0
# 3607        0.9           0.5        0.833333           0.0        1.0
# 26233       0.0           0.5        1.000000           0.0        0.0
# 16023       0.1           0.5        0.166667           1.0        0.0
# 3445        0.1           1.0        0.000000           0.0        0.0
# 15220       0.0           1.0        0.500000           1.0        0.0
# 17960       0.0           1.0        0.500000           0.0        1.0
# 17120       0.0           0.0        1.000000           1.0        0.0
# 881         0.1           0.5        0.333333           1.0        0.0
#
#        contact_code  poutcome_code
# 15252           0.0            0.5
# 27202           0.0            0.5
# 3607            1.0            0.5
# 26233           1.0            0.5
# 16023           0.0            0.5
# 3445            1.0            0.5
# 15220           0.0            0.5
# 17960           0.0            0.5
# 17120           0.0            0.5
# 881             1.0            0.5

# %%
data_converted.isnull().sum()
# Out:
# duration           0
# campaign           0
# previous           0
# emp.var.rate       0
# cons.price.idx     0
# cons.conf.idx      0
# euribor3m          0
# nr.employed        0
# age_period_code    0
# target             0
# job_code           0
# marital_code       0
# education_code     0
# housing_code       0
# loan_code          0
# contact_code       0
# poutcome_code      0
# dtype: int64

# %%
data_converted.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <a id="step4"></a>
# # 4. Step 4 - Data Modeling with Machine Learning

# %% [markdown]
# ## 4.1 Features&Target Split and Modeling Options Definition

# %%
data_cleaned = data_converted.copy()
x_columns = list(data_cleaned.columns)
x_columns.remove('target')
y_columns = ['target']
data_cleaned_x = data_cleaned[x_columns]
data_cleaned_y = data_cleaned[y_columns]

ALGS = [
    #GLM
    linear_model.LogisticRegressionCV(),
    linear_model.SGDClassifier(),
    linear_model.Perceptron(),
    
    #Nearest Neighbor
    neighbors.KNeighborsClassifier(),
    
    #Navies Bayes
    naive_bayes.BernoulliNB(),
    naive_bayes.GaussianNB(),
    
    #Trees    
    tree.DecisionTreeClassifier(),
    
    #SVM
    svm.LinearSVC(),
    svm.SVC(probability=True),
    
    # Ensemble Models
    ensemble.BaggingClassifier(),
    ensemble.RandomForestClassifier(),
    ensemble.AdaBoostClassifier(),
    XGBClassifier(),
    LGBMClassifier(),
    CatBoostClassifier(verbose=False),
]

CV_TRAIN_SIZE, CV_TEST_SIZE, N_SPLITS, RANDOM_STATE = 0.6, 0.3, 10, 4326
# run model 10x with 60/30 split intentionally leaving out 10%
CV_SPLIT = model_selection.ShuffleSplit(n_splits=N_SPLITS, train_size=CV_TRAIN_SIZE, test_size=CV_TEST_SIZE, random_state=RANDOM_STATE) 

def algs_benchmark(data_x, data_y, algs, cv_split):
    MLA_columns = ['MLA Name', 'MLA Parameters','MLA Train Accuracy Mean', 'MLA Test Accuracy Mean', 'MLA Test Accuracy 3*STD' ,'MLA Time']
    MLA_compare = pd.DataFrame(columns=MLA_columns)
    row_index = 0
    
    for alg in algs:
        MLA_name = alg.__class__.__name__
        print(f"==> {MLA_name} Modeling...")
        cv_results = model_selection.cross_validate(alg, data_x.copy(), data_y.copy(), cv=cv_split, return_train_score=True)
        
        MLA_compare.loc[row_index, 'MLA Name'] = MLA_name
        MLA_compare.loc[row_index, 'MLA Parameters'] = str(alg.get_params())
        MLA_compare.loc[row_index, 'MLA Time'] = cv_results['fit_time'].mean()
        MLA_compare.loc[row_index, 'MLA Train Accuracy Mean'] = cv_results['train_score'].mean()
        MLA_compare.loc[row_index, 'MLA Test Accuracy Mean'] = cv_results['test_score'].mean()   
        MLA_compare.loc[row_index, 'MLA Test Accuracy 3*STD'] = cv_results['test_score'].std()*3
        print(f"Train Accuracy Mean: {cv_results['train_score'].mean()}, Test Accuracy Mean: {cv_results['test_score'].mean()}")
        row_index+=1
        
    MLA_compare.sort_values(by=['MLA Test Accuracy Mean'], ascending=False, inplace=True)
    return MLA_compare

def visualize_algs_benchmark_results(algs_benchmark_results):
    sns.barplot(x='MLA Test Accuracy Mean', y='MLA Name', data=algs_benchmark_results, color='g')
    plt.title('Machine Learning Algorithm Accuracy Score \n')
    plt.xlabel('Accuracy Score (%)')
    plt.ylabel('Algorithm')

# %%
data_cleaned[x_columns].info()
data_cleaned[x_columns].sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38184 entries, 0 to 41187
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   duration         38184 non-null  float64
#  1   campaign         38184 non-null  float64
#  2   previous         38184 non-null  float64
#  3   emp.var.rate     38184 non-null  float64
#  4   cons.price.idx   38184 non-null  float64
#  5   cons.conf.idx    38184 non-null  float64
#  6   euribor3m        38184 non-null  float64
#  7   nr.employed      38184 non-null  float64
#  8   age_period_code  38184 non-null  float64
#  9   job_code         38184 non-null  float64
#  10  marital_code     38184 non-null  float64
#  11  education_code   38184 non-null  float64
#  12  housing_code     38184 non-null  float64
#  13  loan_code        38184 non-null  float64
#  14  contact_code     38184 non-null  float64
#  15  poutcome_code    38184 non-null  float64
# dtypes: float64(16)
# memory usage: 5.0 MB
#        duration  campaign  previous  emp.var.rate  cons.price.idx  \
# 14060  0.053070  0.285714  0.000000      1.000000        0.669135
# 34654  0.217771  0.023810  0.000000      0.333333        0.269680
# 3793   0.064050  0.047619  0.000000      0.937500        0.698753
# 36526  0.109597  0.000000  0.000000      0.104167        0.296960
# 30515  0.077877  0.023810  0.142857      0.333333        0.269680
# 37699  0.013217  0.095238  0.000000      0.104167        0.000000
# 40604  0.051240  0.023810  0.285714      0.479167        0.778644
# 6314   0.120171  0.095238  0.000000      0.937500        0.698753
# 27485  0.011997  0.000000  0.000000      0.687500        0.389322
# 10024  0.017080  0.047619  0.000000      1.000000        0.882307
#
#        cons.conf.idx  euribor3m  nr.employed  age_period_code  job_code  \
# 14060       0.338912   0.981410     1.000000             0.00       0.1
# 34654       0.192469   0.143278     0.512287             0.00       0.1
# 3793        0.602510   0.957833     0.859735             0.00       0.0
# 36526       0.418410   0.141918     0.425709             0.25       0.9
# 30515       0.192469   0.163228     0.512287             0.50       0.4
# 37699       0.811715   0.049875     0.425709             0.25       0.0
# 40604       0.556485   0.056450     0.000000             0.00       0.0
# 6314        0.602510   0.957379     0.859735             0.50       0.5
# 27485       0.368201   0.767853     0.877883             0.25       0.0
# 10024       0.376569   0.980277     1.000000             0.00       0.8
#
#        marital_code  education_code  housing_code  loan_code  contact_code  \
# 14060           0.0        0.833333           0.0        0.0           0.0
# 34654           0.5        0.833333           0.0        0.0           0.0
# 3793            1.0        1.000000           1.0        0.0           1.0
# 36526           0.5        1.000000           0.0        0.0           0.0
# 30515           0.5        0.500000           1.0        0.0           0.0
# 37699           0.5        1.000000           0.0        1.0           0.0
# 40604           1.0        0.500000           0.0        0.0           0.0
# 6314            0.5        0.500000           1.0        0.0           1.0
# 27485           0.0        1.000000           0.0        1.0           0.0
# 10024           1.0        0.500000           1.0        0.0           1.0
#
#        poutcome_code
# 14060            0.5
# 34654            0.5
# 3793             0.5
# 36526            0.5
# 30515            0.0
# 37699            0.5
# 40604            1.0
# 6314             0.5
# 27485            0.5
# 10024            0.5

# %%
data_cleaned[y_columns].info()
data_cleaned[y_columns].sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38184 entries, 0 to 41187
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  38184 non-null  float64
# dtypes: float64(1)
# memory usage: 596.6 KB
#        target
# 31815     0.0
# 34337     0.0
# 21004     1.0
# 36799     1.0
# 17911     0.0
# 398       0.0
# 7932      0.0
# 21654     0.0
# 28613     0.0
# 7091      0.0

# %% [markdown]
# ## 4.2 Data Modeling by Machine Learning Algorithms, Get and Visualize Benchmark Results

# %%
algs_benchmark_results = algs_benchmark(data_cleaned_x, data_cleaned_y, ALGS, CV_SPLIT)
algs_benchmark_results
# Out:
# ==> LogisticRegressionCV Modeling...
# Train Accuracy Mean: 0.9099690240390907, Test Accuracy Mean: 0.9084373091353285
# ==> SGDClassifier Modeling...
# Train Accuracy Mean: 0.907063391649579, Test Accuracy Mean: 0.9056452316551784
# ==> Perceptron Modeling...
# Train Accuracy Mean: 0.8400767854805636, Test Accuracy Mean: 0.8394380944071198
# ==> KNeighborsClassifier Modeling...
# Train Accuracy Mean: 0.9209284062649973, Test Accuracy Mean: 0.8948782828723496
# ==> BernoulliNB Modeling...
# Train Accuracy Mean: 0.8858252257754897, Test Accuracy Mean: 0.8852368903237064
# ==> GaussianNB Modeling...
# Train Accuracy Mean: 0.8342698835129359, Test Accuracy Mean: 0.8325102521594975
# ==> DecisionTreeClassifier Modeling...
# Train Accuracy Mean: 0.9999825487544174, Test Accuracy Mean: 0.8874356513393247
# ==> LinearSVC Modeling...
# Train Accuracy Mean: 0.9087256227913267, Test Accuracy Mean: 0.9072594014483902
# ==> SVC Modeling...
# Train Accuracy Mean: 0.9060250425374112, Test Accuracy Mean: 0.9024256173108803
# ==> BaggingClassifier Modeling...
# Train Accuracy Mean: 0.9930544042581039, Test Accuracy Mean: 0.9071808742692611
# ==> RandomForestClassifier Modeling...
# Train Accuracy Mean: 0.9999694603202304, Test Accuracy Mean: 0.9125817991449263
# ==> AdaBoostClassifier Modeling...
# Train Accuracy Mean: 0.9106190829370446, Test Accuracy Mean: 0.9095803158537649
# ==> XGBClassifier Modeling...
# Train Accuracy Mean: 0.964451812748135, Test Accuracy Mean: 0.9139342116743739
# ==> LGBMClassifier Modeling...
# Train Accuracy Mean: 0.942598490467257, Test Accuracy Mean: 0.9160195445423611
# ==> CatBoostClassifier Modeling...
# Train Accuracy Mean: 0.9531826709131366, Test Accuracy Mean: 0.9163685542273798
#                   MLA Name                                     MLA Parameters  \
# 14      CatBoostClassifier                                 {'verbose': False}
# 13          LGBMClassifier  {'boosting_type': 'gbdt', 'class_weight': None...
# 12           XGBClassifier  {'objective': 'binary:logistic', 'use_label_en...
# 10  RandomForestClassifier  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# 11      AdaBoostClassifier  {'algorithm': 'SAMME.R', 'base_estimator': Non...
# 0     LogisticRegressionCV  {'Cs': 10, 'class_weight': None, 'cv': None, '...
# 7                LinearSVC  {'C': 1.0, 'class_weight': None, 'dual': True,...
# 9        BaggingClassifier  {'base_estimator': None, 'bootstrap': True, 'b...
# 1            SGDClassifier  {'alpha': 0.0001, 'average': False, 'class_wei...
# 8                      SVC  {'C': 1.0, 'break_ties': False, 'cache_size': ...
# 3     KNeighborsClassifier  {'algorithm': 'auto', 'leaf_size': 30, 'metric...
# 6   DecisionTreeClassifier  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...
# 4              BernoulliNB  {'alpha': 1.0, 'binarize': 0.0, 'class_prior':...
# 2               Perceptron  {'alpha': 0.0001, 'class_weight': None, 'early...
# 5               GaussianNB           {'priors': None, 'var_smoothing': 1e-09}
#
#    MLA Train Accuracy Mean MLA Test Accuracy Mean MLA Test Accuracy 3*STD  \
# 14                0.953183               0.916369                0.005211
# 13                0.942598                0.91602                0.005322
# 12                0.964452               0.913934                0.005937
# 10                0.999969               0.912582                 0.00493
# 11                0.910619                0.90958                0.008645
# 0                 0.909969               0.908437                0.006926
# 7                 0.908726               0.907259                 0.00695
# 9                 0.993054               0.907181                0.005849
# 1                 0.907063               0.905645                0.006322
# 8                 0.906025               0.902426                0.008432
# 3                 0.920928               0.894878                0.006288
# 6                 0.999983               0.887436                0.007879
# 4                 0.885825               0.885237                0.007309
# 2                 0.840077               0.839438                0.422773
# 5                  0.83427                0.83251                0.008371
#
#      MLA Time
# 14   3.243622
# 13   0.125253
# 12   0.398447
# 10   1.199843
# 11   0.418412
# 0    0.849289
# 7    0.182306
# 9    0.405158
# 1    0.029343
# 8   19.979976
# 3    0.005721
# 6    0.063593
# 4     0.00845
# 2    0.013708
# 5    0.007171

# %%
visualize_algs_benchmark_results(algs_benchmark_results)

# %%
TEST_SIZE = 0.30
data_cleaned_train_x, data_cleaned_test_x, data_cleaned_train_y, data_cleaned_test_y = model_selection.train_test_split(data_cleaned_x, data_cleaned_y, test_size=TEST_SIZE, random_state = 4262)
model = LGBMClassifier()
prams={
    'learning_rate':[0.01,0.03,0.05,0.1,0.15,0.2],
    'n_estimators':[100,200,500,1000,2000],
    'max_depth':[3,5,10],
    'colsample_bytree':[0.1,0.3,0.5,1],
    'subsample':[0.1,0.3,0.5,1]
}
random_model = RandomizedSearchCV(model, param_distributions=prams, verbose=10, n_iter=20, cv=5, scoring='accuracy')
random_model.fit(data_cleaned_train_x, data_cleaned_train_y)
print(random_model.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5; 1/20] START colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=2000, subsample=1
# [CV 1/5; 1/20] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=2000, subsample=1;, score=0.911 total time=   1.7s
# [CV 2/5; 1/20] START colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=2000, subsample=1
# [CV 2/5; 1/20] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=2000, subsample=1;, score=0.914 total time=   1.7s
# [CV 3/5; 1/20] START colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=2000, subsample=1
# [CV 3/5; 1/20] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=2000, subsample=1;, score=0.909 total time=   1.7s
# [CV 4/5; 1/20] START colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=2000, subsample=1
# [CV 4/5; 1/20] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=2000, subsample=1;, score=0.911 total time=   1.6s
# [CV 5/5; 1/20] START colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=2000, subsample=1
# [CV 5/5; 1/20] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, n_estimators=2000, subsample=1;, score=0.911 total time=   1.6s
# [CV 1/5; 2/20] START colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1
# [CV 1/5; 2/20] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1;, score=0.913 total time=   0.1s
# [CV 2/5; 2/20] START colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1
# [CV 2/5; 2/20] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1;, score=0.911 total time=   0.1s
# [CV 3/5; 2/20] START colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1
# [CV 3/5; 2/20] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1;, score=0.912 total time=   0.1s
# [CV 4/5; 2/20] START colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1
# [CV 4/5; 2/20] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1;, score=0.911 total time=   0.1s
# [CV 5/5; 2/20] START colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1
# [CV 5/5; 2/20] END colsample_bytree=0.3, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1;, score=0.909 total time=   0.1s
# [CV 1/5; 3/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.3
# [CV 1/5; 3/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.3;, score=0.908 total time=   1.7s
# [CV 2/5; 3/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.3
# [CV 2/5; 3/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.3;, score=0.909 total time=   1.7s
# [CV 3/5; 3/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.3
# [CV 3/5; 3/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.3;, score=0.905 total time=   1.7s
# [CV 4/5; 3/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.3
# [CV 4/5; 3/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.3;, score=0.906 total time=   1.8s
# [CV 5/5; 3/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.3
# [CV 5/5; 3/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.3;, score=0.908 total time=   1.7s
# [CV 1/5; 4/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 1/5; 4/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.908 total time=   1.7s
# [CV 2/5; 4/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 2/5; 4/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.909 total time=   1.8s
# [CV 3/5; 4/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 3/5; 4/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.905 total time=   1.6s
# [CV 4/5; 4/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 4/5; 4/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.906 total time=   1.7s
# [CV 5/5; 4/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.5
# [CV 5/5; 4/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=10, n_estimators=2000, subsample=0.5;, score=0.908 total time=   1.7s
# [CV 1/5; 5/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=100, subsample=0.5
# [CV 1/5; 5/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=100, subsample=0.5;, score=0.919 total time=   0.1s
# [CV 2/5; 5/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=100, subsample=0.5
# [CV 2/5; 5/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=100, subsample=0.5;, score=0.919 total time=   0.1s
# [CV 3/5; 5/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=100, subsample=0.5
# [CV 3/5; 5/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=100, subsample=0.5;, score=0.912 total time=   0.1s
# [CV 4/5; 5/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=100, subsample=0.5
# [CV 4/5; 5/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=100, subsample=0.5;, score=0.916 total time=   0.1s
# [CV 5/5; 5/20] START colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=100, subsample=0.5
# [CV 5/5; 5/20] END colsample_bytree=0.5, learning_rate=0.15, max_depth=5, n_estimators=100, subsample=0.5;, score=0.918 total time=   0.1s
# [CV 1/5; 6/20] START colsample_bytree=0.1, learning_rate=0.03, max_depth=10, n_estimators=100, subsample=0.3
# [CV 1/5; 6/20] END colsample_bytree=0.1, learning_rate=0.03, max_depth=10, n_estimators=100, subsample=0.3;, score=0.905 total time=   0.1s
# [CV 2/5; 6/20] START colsample_bytree=0.1, learning_rate=0.03, max_depth=10, n_estimators=100, subsample=0.3
# [CV 2/5; 6/20] END colsample_bytree=0.1, learning_rate=0.03, max_depth=10, n_estimators=100, subsample=0.3;, score=0.902 total time=   0.1s
# [CV 3/5; 6/20] START colsample_bytree=0.1, learning_rate=0.03, max_depth=10, n_estimators=100, subsample=0.3
# [CV 3/5; 6/20] END colsample_bytree=0.1, learning_rate=0.03, max_depth=10, n_estimators=100, subsample=0.3;, score=0.902 total time=   0.1s
# [CV 4/5; 6/20] START colsample_bytree=0.1, learning_rate=0.03, max_depth=10, n_estimators=100, subsample=0.3
# [CV 4/5; 6/20] END colsample_bytree=0.1, learning_rate=0.03, max_depth=10, n_estimators=100, subsample=0.3;, score=0.904 total time=   0.1s
# [CV 5/5; 6/20] START colsample_bytree=0.1, learning_rate=0.03, max_depth=10, n_estimators=100, subsample=0.3
# [CV 5/5; 6/20] END colsample_bytree=0.1, learning_rate=0.03, max_depth=10, n_estimators=100, subsample=0.3;, score=0.904 total time=   0.1s
# [CV 1/5; 7/20] START colsample_bytree=0.3, learning_rate=0.03, max_depth=3, n_estimators=2000, subsample=0.1
# [CV 1/5; 7/20] END colsample_bytree=0.3, learning_rate=0.03, max_depth=3, n_estimators=2000, subsample=0.1;, score=0.920 total time=   0.9s
# [CV 2/5; 7/20] START colsample_bytree=0.3, learning_rate=0.03, max_depth=3, n_estimators=2000, subsample=0.1
# [CV 2/5; 7/20] END colsample_bytree=0.3, learning_rate=0.03, max_depth=3, n_estimators=2000, subsample=0.1;, score=0.917 total time=   0.9s
# [CV 3/5; 7/20] START colsample_bytree=0.3, learning_rate=0.03, max_depth=3, n_estimators=2000, subsample=0.1
# [CV 3/5; 7/20] END colsample_bytree=0.3, learning_rate=0.03, max_depth=3, n_estimators=2000, subsample=0.1;, score=0.915 total time=   0.9s
# [CV 4/5; 7/20] START colsample_bytree=0.3, learning_rate=0.03, max_depth=3, n_estimators=2000, subsample=0.1
# [CV 4/5; 7/20] END colsample_bytree=0.3, learning_rate=0.03, max_depth=3, n_estimators=2000, subsample=0.1;, score=0.915 total time=   0.9s
# [CV 5/5; 7/20] START colsample_bytree=0.3, learning_rate=0.03, max_depth=3, n_estimators=2000, subsample=0.1
# [CV 5/5; 7/20] END colsample_bytree=0.3, learning_rate=0.03, max_depth=3, n_estimators=2000, subsample=0.1;, score=0.918 total time=   0.9s
# [CV 1/5; 8/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.5
# [CV 1/5; 8/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.5;, score=0.909 total time=   0.4s
# [CV 2/5; 8/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.5
# [CV 2/5; 8/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.5;, score=0.908 total time=   0.4s
# [CV 3/5; 8/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.5
# [CV 3/5; 8/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.5;, score=0.910 total time=   0.4s
# [CV 4/5; 8/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.5
# [CV 4/5; 8/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.5;, score=0.907 total time=   0.4s
# [CV 5/5; 8/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.5
# [CV 5/5; 8/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=500, subsample=0.5;, score=0.908 total time=   0.4s
# [CV 1/5; 9/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=100, subsample=0.5
# [CV 1/5; 9/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=100, subsample=0.5;, score=0.909 total time=   0.1s
# [CV 2/5; 9/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=100, subsample=0.5
# [CV 2/5; 9/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=100, subsample=0.5;, score=0.909 total time=   0.1s
# [CV 3/5; 9/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=100, subsample=0.5
# [CV 3/5; 9/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=100, subsample=0.5;, score=0.912 total time=   0.1s
# [CV 4/5; 9/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=100, subsample=0.5
# [CV 4/5; 9/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=100, subsample=0.5;, score=0.911 total time=   0.1s
# [CV 5/5; 9/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=100, subsample=0.5
# [CV 5/5; 9/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=3, n_estimators=100, subsample=0.5;, score=0.909 total time=   0.1s
# [CV 1/5; 10/20] START colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.3
# [CV 1/5; 10/20] END colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.3;, score=0.909 total time=   0.5s
# [CV 2/5; 10/20] START colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.3
# [CV 2/5; 10/20] END colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.3;, score=0.914 total time=   0.5s
# [CV 3/5; 10/20] START colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.3
# [CV 3/5; 10/20] END colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.3;, score=0.910 total time=   0.5s
# [CV 4/5; 10/20] START colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.3
# [CV 4/5; 10/20] END colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.3;, score=0.909 total time=   0.5s
# [CV 5/5; 10/20] START colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.3
# [CV 5/5; 10/20] END colsample_bytree=0.3, learning_rate=0.2, max_depth=10, n_estimators=500, subsample=0.3;, score=0.910 total time=   0.5s
# [CV 1/5; 11/20] START colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3
# [CV 1/5; 11/20] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3;, score=0.916 total time=   0.1s
# [CV 2/5; 11/20] START colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3
# [CV 2/5; 11/20] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3;, score=0.915 total time=   0.1s
# [CV 3/5; 11/20] START colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3
# [CV 3/5; 11/20] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3;, score=0.913 total time=   0.1s
# [CV 4/5; 11/20] START colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3
# [CV 4/5; 11/20] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3;, score=0.913 total time=   0.1s
# [CV 5/5; 11/20] START colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3
# [CV 5/5; 11/20] END colsample_bytree=1, learning_rate=0.2, max_depth=5, n_estimators=100, subsample=0.3;, score=0.912 total time=   0.1s
# [CV 1/5; 12/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=10, n_estimators=200, subsample=1
# [CV 1/5; 12/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=10, n_estimators=200, subsample=1;, score=0.918 total time=   0.3s
# [CV 2/5; 12/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=10, n_estimators=200, subsample=1
# [CV 2/5; 12/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=10, n_estimators=200, subsample=1;, score=0.918 total time=   0.3s
# [CV 3/5; 12/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=10, n_estimators=200, subsample=1
# [CV 3/5; 12/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=10, n_estimators=200, subsample=1;, score=0.917 total time=   0.3s
# [CV 4/5; 12/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=10, n_estimators=200, subsample=1
# [CV 4/5; 12/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=10, n_estimators=200, subsample=1;, score=0.916 total time=   0.2s
# [CV 5/5; 12/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=10, n_estimators=200, subsample=1
# [CV 5/5; 12/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=10, n_estimators=200, subsample=1;, score=0.919 total time=   0.3s
# [CV 1/5; 13/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.1
# [CV 1/5; 13/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.1;, score=0.912 total time=   0.7s
# [CV 2/5; 13/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.1
# [CV 2/5; 13/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.1;, score=0.915 total time=   0.7s
# [CV 3/5; 13/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.1
# [CV 3/5; 13/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.1;, score=0.915 total time=   0.7s
# [CV 4/5; 13/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.1
# [CV 4/5; 13/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.1;, score=0.912 total time=   0.7s
# [CV 5/5; 13/20] START colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.1
# [CV 5/5; 13/20] END colsample_bytree=0.1, learning_rate=0.01, max_depth=5, n_estimators=1000, subsample=0.1;, score=0.912 total time=   0.7s
# [CV 1/5; 14/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=200, subsample=0.5
# [CV 1/5; 14/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=200, subsample=0.5;, score=0.915 total time=   0.2s
# [CV 2/5; 14/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=200, subsample=0.5
# [CV 2/5; 14/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=200, subsample=0.5;, score=0.918 total time=   0.2s
# [CV 3/5; 14/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=200, subsample=0.5
# [CV 3/5; 14/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=200, subsample=0.5;, score=0.916 total time=   0.2s
# [CV 4/5; 14/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=200, subsample=0.5
# [CV 4/5; 14/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=200, subsample=0.5;, score=0.917 total time=   0.2s
# [CV 5/5; 14/20] START colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=200, subsample=0.5
# [CV 5/5; 14/20] END colsample_bytree=0.5, learning_rate=0.03, max_depth=5, n_estimators=200, subsample=0.5;, score=0.918 total time=   0.2s
# [CV 1/5; 15/20] START colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=2000, subsample=0.5
# [CV 1/5; 15/20] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=2000, subsample=0.5;, score=0.914 total time=   0.9s
# [CV 2/5; 15/20] START colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=2000, subsample=0.5
# [CV 2/5; 15/20] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=2000, subsample=0.5;, score=0.919 total time=   0.9s
# [CV 3/5; 15/20] START colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=2000, subsample=0.5
# [CV 3/5; 15/20] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=2000, subsample=0.5;, score=0.911 total time=   0.9s
# [CV 4/5; 15/20] START colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=2000, subsample=0.5
# [CV 4/5; 15/20] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=2000, subsample=0.5;, score=0.914 total time=   0.9s
# [CV 5/5; 15/20] START colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=2000, subsample=0.5
# [CV 5/5; 15/20] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=2000, subsample=0.5;, score=0.916 total time=   0.9s
# [CV 1/5; 16/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=2000, subsample=0.5
# [CV 1/5; 16/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=2000, subsample=0.5;, score=0.915 total time=   0.8s
# [CV 2/5; 16/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=2000, subsample=0.5
# [CV 2/5; 16/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=2000, subsample=0.5;, score=0.918 total time=   0.9s
# [CV 3/5; 16/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=2000, subsample=0.5
# [CV 3/5; 16/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=2000, subsample=0.5;, score=0.915 total time=   0.8s
# [CV 4/5; 16/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=2000, subsample=0.5
# [CV 4/5; 16/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=2000, subsample=0.5;, score=0.913 total time=   0.9s
# [CV 5/5; 16/20] START colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=2000, subsample=0.5
# [CV 5/5; 16/20] END colsample_bytree=0.1, learning_rate=0.15, max_depth=3, n_estimators=2000, subsample=0.5;, score=0.916 total time=   0.8s
# [CV 1/5; 17/20] START colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.3
# [CV 1/5; 17/20] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.3;, score=0.917 total time=   0.2s
# [CV 2/5; 17/20] START colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.3
# [CV 2/5; 17/20] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.3;, score=0.918 total time=   0.2s
# [CV 3/5; 17/20] START colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.3
# [CV 3/5; 17/20] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.3;, score=0.913 total time=   0.2s
# [CV 4/5; 17/20] START colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.3
# [CV 4/5; 17/20] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.3;, score=0.913 total time=   0.2s
# [CV 5/5; 17/20] START colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.3
# [CV 5/5; 17/20] END colsample_bytree=1, learning_rate=0.2, max_depth=3, n_estimators=500, subsample=0.3;, score=0.914 total time=   0.2s
# [CV 1/5; 18/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.5
# [CV 1/5; 18/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.5;, score=0.910 total time=   0.9s
# [CV 2/5; 18/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.5
# [CV 2/5; 18/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.5;, score=0.914 total time=   0.8s
# [CV 3/5; 18/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.5
# [CV 3/5; 18/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.5;, score=0.909 total time=   0.8s
# [CV 4/5; 18/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.5
# [CV 4/5; 18/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.5;, score=0.913 total time=   0.7s
# [CV 5/5; 18/20] START colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.5
# [CV 5/5; 18/20] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000, subsample=0.5;, score=0.911 total time=   0.8s
# [CV 1/5; 19/20] START colsample_bytree=1, learning_rate=0.05, max_depth=10, n_estimators=100, subsample=0.5
# [CV 1/5; 19/20] END colsample_bytree=1, learning_rate=0.05, max_depth=10, n_estimators=100, subsample=0.5;, score=0.915 total time=   0.2s
# [CV 2/5; 19/20] START colsample_bytree=1, learning_rate=0.05, max_depth=10, n_estimators=100, subsample=0.5
# [CV 2/5; 19/20] END colsample_bytree=1, learning_rate=0.05, max_depth=10, n_estimators=100, subsample=0.5;, score=0.918 total time=   0.2s
# [CV 3/5; 19/20] START colsample_bytree=1, learning_rate=0.05, max_depth=10, n_estimators=100, subsample=0.5
# [CV 3/5; 19/20] END colsample_bytree=1, learning_rate=0.05, max_depth=10, n_estimators=100, subsample=0.5;, score=0.917 total time=   0.2s
# [CV 4/5; 19/20] START colsample_bytree=1, learning_rate=0.05, max_depth=10, n_estimators=100, subsample=0.5
# [CV 4/5; 19/20] END colsample_bytree=1, learning_rate=0.05, max_depth=10, n_estimators=100, subsample=0.5;, score=0.917 total time=   0.1s
# [CV 5/5; 19/20] START colsample_bytree=1, learning_rate=0.05, max_depth=10, n_estimators=100, subsample=0.5
# [CV 5/5; 19/20] END colsample_bytree=1, learning_rate=0.05, max_depth=10, n_estimators=100, subsample=0.5;, score=0.917 total time=   0.1s
# [CV 1/5; 20/20] START colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1
# [CV 1/5; 20/20] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1;, score=0.915 total time=   0.5s
# [CV 2/5; 20/20] START colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1
# [CV 2/5; 20/20] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1;, score=0.918 total time=   0.5s
# [CV 3/5; 20/20] START colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1
# [CV 3/5; 20/20] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1;, score=0.917 total time=   0.5s
# [CV 4/5; 20/20] START colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1
# [CV 4/5; 20/20] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1;, score=0.916 total time=   0.5s
# [CV 5/5; 20/20] START colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1
# [CV 5/5; 20/20] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1;, score=0.917 total time=   0.5s
# {'subsample': 1, 'n_estimators': 200, 'max_depth': 10, 'learning_rate': 0.03, 'colsample_bytree': 0.5}

# %%
model = LGBMClassifier(n_estimators=200, max_depth=10, learning_rate=0.03, \
                    colsample_bytree=0.5, subsample=1)
model.fit(data_cleaned_train_x, data_cleaned_train_y)
data_cleaned_test_y_predict = model.predict(data_cleaned_test_x)
print(accuracy_score(data_cleaned_test_y, data_cleaned_test_y_predict), roc_auc_score(data_cleaned_test_y, data_cleaned_test_y_predict))
# Out:
# 0.9167611901230259 0.7405732337058628

# %% [markdown]
# <a id="step5"></a>
# # 5. Step 5 - Conclusion
